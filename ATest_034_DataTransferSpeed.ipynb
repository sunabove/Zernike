# %%
from ATest_040_DataTransferSpeed import *

Ks = torch.arange( 1, 10 + 1, 1 )
Ks = torch.arange( 3, 12 + 1, 1 )

test_data_transfer_speed( Ks, debug=1 )
# Out:
# Hello ...
#
# CPU : free_mem_bytes = 164_102_930_432 bytes 97%%
# GPU : free_mem_bytes = 12_449_611_776 bytes 97%%
#
# [ 3%] device fr = cpu, to = cuda:0, k = 3, speed = 6.8 (Gbps), size =  72.00 Mb, run_time = 0.212039 (sec.)
# [ 7%] device fr = cpu, to = cuda:0, k = 4, speed = 6.9 (Gbps), size = 128.00 Mb, run_time = 0.373249 (sec.)
# [10%] device fr = cpu, to = cuda:0, k = 5, speed = 6.9 (Gbps), size = 200.00 Mb, run_time = 0.579704 (sec.)
# [13%] device fr = cpu, to = cuda:0, k = 6, speed = 6.9 (Gbps), size = 288.00 Mb, run_time = 0.833167 (sec.)
# [17%] device fr = cpu, to = cuda:0, k = 7, speed = 6.9 (Gbps), size = 392.00 Mb, run_time = 1.136981 (sec.)
# [20%] device fr = cpu, to = cuda:0, k = 8, speed = 6.9 (Gbps), size = 512.00 Mb, run_time = 1.484647 (sec.)
# [23%] device fr = cpu, to = cuda:0, k = 9, speed = 6.9 (Gbps), size = 648.00 Mb, run_time = 1.877676 (sec.)
# [27%] device fr = cpu, to = cuda:0, k = 10, speed = 6.9 (Gbps), size = 800.00 Mb, run_time = 2.310914 (sec.)
# [30%] device fr = cpu, to = cuda:0, k = 11, speed = 6.9 (Gbps), size = 968.00 Mb, run_time = 2.817657 (sec.)
# [33%] device fr = cpu, to = cuda:0, k = 12, speed = 3.6 (Gbps), size = 1152.00 Mb, run_time = 6.312769 (sec.)
#
# CPU : free_mem_bytes = 163_961_307_136 bytes 97%%
# GPU : free_mem_bytes = 12_432_834_560 bytes 97%%
#
# [37%] device fr = cuda:0, to = cpu, k = 3, speed = 1.8 (Gbps), size =  72.00 Mb, run_time = 0.783580 (sec.)
# [40%] device fr = cuda:0, to = cpu, k = 4, speed = 1.8 (Gbps), size = 128.00 Mb, run_time = 1.394707 (sec.)
# [43%] device fr = cuda:0, to = cpu, k = 5, speed = 1.8 (Gbps), size = 200.00 Mb, run_time = 2.177944 (sec.)
# [47%] device fr = cuda:0, to = cpu, k = 6, speed = 1.8 (Gbps), size = 288.00 Mb, run_time = 3.132749 (sec.)
# [50%] device fr = cuda:0, to = cpu, k = 7, speed = 1.7 (Gbps), size = 392.00 Mb, run_time = 4.631524 (sec.)
# [53%] device fr = cuda:0, to = cpu, k = 8, speed = 1.7 (Gbps), size = 512.00 Mb, run_time = 6.002610 (sec.)
# [57%] device fr = cuda:0, to = cpu, k = 9, speed = 1.5 (Gbps), size = 648.00 Mb, run_time = 8.483537 (sec.)
# [60%] device fr = cuda:0, to = cpu, k = 10, speed = 1.5 (Gbps), size = 800.00 Mb, run_time = 10.468345 (sec.)
# [63%] device fr = cuda:0, to = cpu, k = 11, speed = 1.5 (Gbps), size = 968.00 Mb, run_time = 12.653328 (sec.)
# [67%] device fr = cuda:0, to = cpu, k = 12, speed = 1.5 (Gbps), size = 1152.00 Mb, run_time = 15.040947 (sec.)
#
# CPU : free_mem_bytes = 163_973_656_576 bytes 97%%
# GPU : free_mem_bytes = 12_432_834_560 bytes 97%%
#
# [70%] device fr = cuda:0, to = cuda:1, k = 3, speed = 411.1 (Gbps), size =  72.00 Mb, run_time = 0.003503 (sec.)
# [73%] device fr = cuda:0, to = cuda:1, k = 4, speed = 1,222.4 (Gbps), size = 128.00 Mb, run_time = 0.002094 (sec.)
# [77%] device fr = cuda:0, to = cuda:1, k = 5, speed = 1,034.7 (Gbps), size = 200.00 Mb, run_time = 0.003866 (sec.)
# [80%] device fr = cuda:0, to = cuda:1, k = 6, speed = 1,319.5 (Gbps), size = 288.00 Mb, run_time = 0.004365 (sec.)
# [83%] device fr = cuda:0, to = cuda:1, k = 7, speed = 1,099.2 (Gbps), size = 392.00 Mb, run_time = 0.007133 (sec.)
# [87%] device fr = cuda:0, to = cuda:1, k = 8, speed = 1,591.1 (Gbps), size = 512.00 Mb, run_time = 0.006436 (sec.)
# [90%] device fr = cuda:0, to = cuda:1, k = 9, speed = 1,893.1 (Gbps), size = 648.00 Mb, run_time = 0.006846 (sec.)
# [93%] device fr = cuda:0, to = cuda:1, k = 10, speed = 2,316.3 (Gbps), size = 800.00 Mb, run_time = 0.006907 (sec.)
# [97%] device fr = cuda:0, to = cuda:1, k = 11, speed = 2,794.3 (Gbps), size = 968.00 Mb, run_time = 0.006928 (sec.)
# [100%] device fr = cuda:0, to = cuda:1, k = 12, speed = 2,381.6 (Gbps), size = 1152.00 Mb, run_time = 0.009674 (sec.)
#
# Result figure file = /home/machine/Zernike/result/test_070_data_transfer_speed.png
# FROM    TO             AVG         3K          4K          5K          6K          7K          8K          9K         10K         11K         12K
# ------  ------  ----------  ---------  ----------  ----------  ----------  ----------  ----------  ----------  ----------  ----------  ----------
# cpu     cuda:0     6.56026    6.79121     6.85869     6.90007     6.91338     6.89545     6.89726     6.90215     6.92367     6.87096     3.64975
# cuda:0  cpu        1.68651    1.83772     1.83551     1.83659     1.83864     1.69275     1.70592     1.52766     1.52842     1.53003     1.53182
# cuda:0  cuda:1  1606.33     411.122    1222.38     1034.67     1319.53     1099.15     1591.14     1893.09     2316.34     2794.28     2381.62
#
# Excel file = /home/machine/Zernike/result/test_070_data_transfer_speed.xlsx
#
# Done.
