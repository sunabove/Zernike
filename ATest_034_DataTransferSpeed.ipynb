# %%
from ATest_034_DataTransferSpeed import *

Ks = torch.arange( 1, 10 + 1, 1 )
Ks = torch.arange( 3, 12 + 1, 1 )

test_data_transfer_speed( Ks, debug=1 )
# Out:
# Hello ...
#
# CPU : free_mem_bytes = 164_657_717_248 bytes 98%%
# GPU : free_mem_bytes = 12_449_611_776 bytes 97%%
#
# [ 3%] device fr = cpu, to = cuda:0, k = 3, speed = 3.5 (Gbps), size =  72.00 Mb, run_time = 0.408175 (sec.)
# [ 7%] device fr = cpu, to = cuda:0, k = 4, speed = 3.5 (Gbps), size = 128.00 Mb, run_time = 0.735709 (sec.)
# [10%] device fr = cpu, to = cuda:0, k = 5, speed = 3.5 (Gbps), size = 200.00 Mb, run_time = 1.150007 (sec.)
# [13%] device fr = cpu, to = cuda:0, k = 6, speed = 3.5 (Gbps), size = 288.00 Mb, run_time = 1.647467 (sec.)
# [17%] device fr = cpu, to = cuda:0, k = 7, speed = 3.5 (Gbps), size = 392.00 Mb, run_time = 2.240677 (sec.)
# [20%] device fr = cpu, to = cuda:0, k = 8, speed = 3.4 (Gbps), size = 512.00 Mb, run_time = 2.980757 (sec.)
# [23%] device fr = cpu, to = cuda:0, k = 9, speed = 3.4 (Gbps), size = 648.00 Mb, run_time = 3.864212 (sec.)
# [27%] device fr = cpu, to = cuda:0, k = 10, speed = 3.5 (Gbps), size = 800.00 Mb, run_time = 4.581162 (sec.)
# [30%] device fr = cpu, to = cuda:0, k = 11, speed = 3.5 (Gbps), size = 968.00 Mb, run_time = 5.536839 (sec.)
# [33%] device fr = cpu, to = cuda:0, k = 12, speed = 1.5 (Gbps), size = 1152.00 Mb, run_time = 15.066358 (sec.)
#
# CPU : free_mem_bytes = 164_717_133_824 bytes 98%%
# GPU : free_mem_bytes = 12_432_834_560 bytes 97%%
#
# [37%] device fr = cuda:0, to = cpu, k = 3, speed = 1.8 (Gbps), size =  72.00 Mb, run_time = 0.786751 (sec.)
# [40%] device fr = cuda:0, to = cpu, k = 4, speed = 1.8 (Gbps), size = 128.00 Mb, run_time = 1.396760 (sec.)
# [43%] device fr = cuda:0, to = cpu, k = 5, speed = 1.8 (Gbps), size = 200.00 Mb, run_time = 2.182519 (sec.)
# [47%] device fr = cuda:0, to = cpu, k = 6, speed = 1.8 (Gbps), size = 288.00 Mb, run_time = 3.148000 (sec.)
# [50%] device fr = cuda:0, to = cpu, k = 7, speed = 1.8 (Gbps), size = 392.00 Mb, run_time = 4.294787 (sec.)
# [53%] device fr = cuda:0, to = cpu, k = 8, speed = 1.8 (Gbps), size = 512.00 Mb, run_time = 5.602281 (sec.)
# [57%] device fr = cuda:0, to = cpu, k = 9, speed = 1.8 (Gbps), size = 648.00 Mb, run_time = 7.081816 (sec.)
# [60%] device fr = cuda:0, to = cpu, k = 10, speed = 1.8 (Gbps), size = 800.00 Mb, run_time = 8.746169 (sec.)
# [63%] device fr = cuda:0, to = cpu, k = 11, speed = 1.8 (Gbps), size = 968.00 Mb, run_time = 10.643395 (sec.)
# [67%] device fr = cuda:0, to = cpu, k = 12, speed = 1.8 (Gbps), size = 1152.00 Mb, run_time = 12.690899 (sec.)
#
# CPU : free_mem_bytes = 164_622_069_760 bytes 97%%
# GPU : free_mem_bytes = 12_432_834_560 bytes 97%%
#
# [70%] device fr = cuda:0, to = cuda:1, k = 3, speed = 294.2 (Gbps), size =  72.00 Mb, run_time = 0.004894 (sec.)
# [73%] device fr = cuda:0, to = cuda:1, k = 4, speed = 1,412.3 (Gbps), size = 128.00 Mb, run_time = 0.001813 (sec.)
# [77%] device fr = cuda:0, to = cuda:1, k = 5, speed = 1,086.3 (Gbps), size = 200.00 Mb, run_time = 0.003682 (sec.)
# [80%] device fr = cuda:0, to = cuda:1, k = 6, speed = 1,024.8 (Gbps), size = 288.00 Mb, run_time = 0.005620 (sec.)
# [83%] device fr = cuda:0, to = cuda:1, k = 7, speed = 1,132.7 (Gbps), size = 392.00 Mb, run_time = 0.006922 (sec.)
# [87%] device fr = cuda:0, to = cuda:1, k = 8, speed = 1,620.7 (Gbps), size = 512.00 Mb, run_time = 0.006318 (sec.)
# [90%] device fr = cuda:0, to = cuda:1, k = 9, speed = 1,950.4 (Gbps), size = 648.00 Mb, run_time = 0.006645 (sec.)
# [93%] device fr = cuda:0, to = cuda:1, k = 10, speed = 2,436.7 (Gbps), size = 800.00 Mb, run_time = 0.006566 (sec.)
# [97%] device fr = cuda:0, to = cuda:1, k = 11, speed = 2,736.6 (Gbps), size = 968.00 Mb, run_time = 0.007074 (sec.)
# [100%] device fr = cuda:0, to = cuda:1, k = 12, speed = 2,439.8 (Gbps), size = 1152.00 Mb, run_time = 0.009444 (sec.)
#
# Result figure file = /home/machine/Zernike/result/test_070_data_transfer_speed.png
# FROM    TO             AVG         3K          4K          5K          6K          7K          8K          9K         10K         11K         12K
# ------  ------  ----------  ---------  ----------  ----------  ----------  ----------  ----------  ----------  ----------  ----------  ----------
# cpu     cuda:0     3.27886    3.52789     3.47964     3.47824     3.49628     3.49894     3.43537     3.35385     3.49256     3.49658     1.52923
# cuda:0  cpu        1.82728    1.83031     1.83281     1.83274     1.82973     1.82547     1.82783     1.83004     1.82937     1.81897     1.81547
# cuda:0  cuda:1  1613.46     294.237    1412.26     1086.33     1024.82     1132.66     1620.74     1950.42     2436.69     2736.64     2439.77
#
# Excel file = /home/machine/Zernike/result/test_070_data_transfer_speed.xlsx
#
# Done.
