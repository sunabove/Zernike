# %%
from ATest_034_DataTransferSpeed import *

Ks = torch.arange( 3, 12 + 1, 1 )
Ks = torch.arange( 1, 10 + 1, 1 )

test_data_transfer_speed( Ks, debug=1 )
# Out:
# Hello ...
#
# CPU : free_mem_bytes = 165_256_941_568 bytes 98%%
# GPU : free_mem_bytes = 12_619_481_088 bytes 99%%
#
# [ 3%] device fr = cpu, to = cuda:0, k = 1, speed = 3.4 (Gbps), size =   8.00 Mb, run_time = 0.047260 (sec.)
# [ 7%] device fr = cpu, to = cuda:0, k = 2, speed = 2.8 (Gbps), size =  32.00 Mb, run_time = 0.227273 (sec.)
# [10%] device fr = cpu, to = cuda:0, k = 3, speed = 3.5 (Gbps), size =  72.00 Mb, run_time = 0.412243 (sec.)
# [13%] device fr = cpu, to = cuda:0, k = 4, speed = 3.3 (Gbps), size = 128.00 Mb, run_time = 0.775745 (sec.)
# [17%] device fr = cpu, to = cuda:0, k = 5, speed = 3.4 (Gbps), size = 200.00 Mb, run_time = 1.187133 (sec.)
# [20%] device fr = cpu, to = cuda:0, k = 6, speed = 3.4 (Gbps), size = 288.00 Mb, run_time = 1.676550 (sec.)
# [23%] device fr = cpu, to = cuda:0, k = 7, speed = 3.4 (Gbps), size = 392.00 Mb, run_time = 2.282889 (sec.)
# [27%] device fr = cpu, to = cuda:0, k = 8, speed = 3.4 (Gbps), size = 512.00 Mb, run_time = 2.981808 (sec.)
# [30%] device fr = cpu, to = cuda:0, k = 9, speed = 3.4 (Gbps), size = 648.00 Mb, run_time = 3.778409 (sec.)
# [33%] device fr = cpu, to = cuda:0, k = 10, speed = 3.4 (Gbps), size = 800.00 Mb, run_time = 4.658907 (sec.)
#
# CPU : free_mem_bytes = 165_053_943_808 bytes 98%%
# GPU : free_mem_bytes = 12_602_703_872 bytes 99%%
#
# [37%] device fr = cuda:0, to = cpu, k = 1, speed = 3.3 (Gbps), size =   8.00 Mb, run_time = 0.048824 (sec.)
# [40%] device fr = cuda:0, to = cpu, k = 2, speed = 3.3 (Gbps), size =  32.00 Mb, run_time = 0.191410 (sec.)
# [43%] device fr = cuda:0, to = cpu, k = 3, speed = 1.7 (Gbps), size =  72.00 Mb, run_time = 0.854244 (sec.)
# [47%] device fr = cuda:0, to = cpu, k = 4, speed = 1.7 (Gbps), size = 128.00 Mb, run_time = 1.511760 (sec.)
# [50%] device fr = cuda:0, to = cpu, k = 5, speed = 1.7 (Gbps), size = 200.00 Mb, run_time = 2.408955 (sec.)
# [53%] device fr = cuda:0, to = cpu, k = 6, speed = 1.7 (Gbps), size = 288.00 Mb, run_time = 3.406376 (sec.)
# [57%] device fr = cuda:0, to = cpu, k = 7, speed = 1.7 (Gbps), size = 392.00 Mb, run_time = 4.637565 (sec.)
# [60%] device fr = cuda:0, to = cpu, k = 8, speed = 1.7 (Gbps), size = 512.00 Mb, run_time = 6.044448 (sec.)
# [63%] device fr = cuda:0, to = cpu, k = 9, speed = 1.7 (Gbps), size = 648.00 Mb, run_time = 7.650226 (sec.)
# [67%] device fr = cuda:0, to = cpu, k = 10, speed = 1.7 (Gbps), size = 800.00 Mb, run_time = 9.451115 (sec.)
#
# CPU : free_mem_bytes = 165_089_607_680 bytes 98%%
# GPU : free_mem_bytes = 12_602_703_872 bytes 99%%
#
# [70%] device fr = cuda:0, to = cuda:1, k = 1, speed = 32.3 (Gbps), size =   8.00 Mb, run_time = 0.004956 (sec.)
# [73%] device fr = cuda:0, to = cuda:1, k = 2, speed = 789.7 (Gbps), size =  32.00 Mb, run_time = 0.000810 (sec.)
# [77%] device fr = cuda:0, to = cuda:1, k = 3, speed = 1,698.5 (Gbps), size =  72.00 Mb, run_time = 0.000848 (sec.)
# [80%] device fr = cuda:0, to = cuda:1, k = 4, speed = 1,462.9 (Gbps), size = 128.00 Mb, run_time = 0.001750 (sec.)
# [83%] device fr = cuda:0, to = cuda:1, k = 5, speed = 1,180.8 (Gbps), size = 200.00 Mb, run_time = 0.003387 (sec.)
# [87%] device fr = cuda:0, to = cuda:1, k = 6, speed = 989.0 (Gbps), size = 288.00 Mb, run_time = 0.005824 (sec.)
# [90%] device fr = cuda:0, to = cuda:1, k = 7, speed = 1,149.6 (Gbps), size = 392.00 Mb, run_time = 0.006820 (sec.)
# [93%] device fr = cuda:0, to = cuda:1, k = 8, speed = 1,627.3 (Gbps), size = 512.00 Mb, run_time = 0.006293 (sec.)
# [97%] device fr = cuda:0, to = cuda:1, k = 9, speed = 1,955.6 (Gbps), size = 648.00 Mb, run_time = 0.006627 (sec.)
# [100%] device fr = cuda:0, to = cuda:1, k = 10, speed = 2,455.7 (Gbps), size = 800.00 Mb, run_time = 0.006516 (sec.)
#
# Result figure file = /home/machine/Zernike/result/atest_034_datatransferspeed.png
# FROM    TO             AVG        1K         2K          3K          4K          5K         6K          7K          8K          9K         10K
# ------  ------  ----------  --------  ---------  ----------  ----------  ----------  ---------  ----------  ----------  ----------  ----------
# cpu     cuda:0     3.35325   3.38556    2.81599     3.49309     3.30005     3.36946    3.43563     3.43424     3.43416     3.43002     3.43428
# cuda:0  cpu        2.01228   3.27707    3.34362     1.6857      1.69339     1.66047    1.69095     1.69054     1.69412     1.69407     1.69292
# cuda:0  cuda:1  1334.14     32.2825   789.748    1698.48     1462.86     1180.83     989.036    1149.57     1627.25     1955.61     2455.68
#
# Excel file = /home/machine/Zernike/result/atest_034_datatransferspeed.xlsx
#
# Done.
