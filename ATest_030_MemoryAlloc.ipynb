# %%
from ATest_030_MemoryAlloc import *

use_gpus = [ 0 ]

test_array_memory_alloc( use_gpus=use_gpus, operation="", debug=1  )
# Out:
# Hello...
#
# operation =
#
# device name = cpu
# idx = [0]
# cpu int32(4 bytes)
# free_mem_bytes = 165_479_874_560 bytes 98%%
# free_mem_bytes after gc= 165_578_620_928 bytes 98%%
# tick_count = 198_245, size = 157.2 Gb, run-time = 12.843017 (sec.)
# sleep( 1 )
#
# idx = [1]
# cpu float64(8 bytes)
# free_mem_bytes = 165_578_584_064 bytes 98%%
# free_mem_bytes after gc= 165_640_646_656 bytes 98%%
# tick_count = 140_222, size = 157.3 Gb, run-time = 13.115471 (sec.)
# sleep( 1 )
#
# idx = [2]
# cpu complex64(8 bytes)
# free_mem_bytes = 165_640_474_624 bytes 98%%
# free_mem_bytes after gc= 165_638_041_600 bytes 98%%
# tick_count = 140_249, size = 157.4 Gb, run-time = 12.518083 (sec.)
# sleep( 1 )
#
# idx = [3]
# cpu complex128(16 bytes)
# free_mem_bytes = 165_638_610_944 bytes 98%%
# free_mem_bytes after gc= 165_630_218_240 bytes 98%%
# tick_count = 99_170, size = 157.4 Gb, run-time = 12.566563 (sec.)
# sleep( 1 )
#
# miny = 0, maxy = 202.0
# Result figure file = /home/machine/Zernike/result/test_030_memory_allocation_0.png
# Done.

# %%
from IPython.display import clear_output
clear_output()

from ATest_030_MemoryAlloc import *

use_gpus = [ 1 ]
operation = ""

test_array_memory_alloc( use_gpus=use_gpus, operation=operation, debug=1  )
# Out:
# operation =
#
# device name = cuda
# idx = [0]
# cuda int32(4 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 54_705, size = 12.0 Gb, run-time = 0.000667 (sec.)
# sleep( 1 )
#
# idx = [1]
# cuda float64(8 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 38_682, size = 12.0 Gb, run-time = 0.001259 (sec.)
# sleep( 1 )
#
# idx = [2]
# cuda complex64(8 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 38_682, size = 12.0 Gb, run-time = 0.000957 (sec.)
# sleep( 1 )
#
# idx = [3]
# cuda complex128(16 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 27_352, size = 12.0 Gb, run-time = 0.001132 (sec.)
# sleep( 1 )
#
# miny = -6.0, maxy = 56.0
# Result figure file = /home/machine/Zernike/result/test_030_memory_allocation_0.png
# Done.

# %%
from IPython.display import clear_output
clear_output()

from ATest_030_MemoryAlloc import *

use_gpus = [ 0 ]
operation = "*"

test_array_memory_alloc( use_gpus=use_gpus, operation=operation, debug=1 )
# Out:
# operation = *
#
# device name = cpu
# idx = [0]
# cpu int32(4 bytes)
# free_mem_bytes = 165_358_120_960 bytes 98%%
# free_mem_bytes after gc= 165_373_362_176 bytes 98%%
# tick_count = 114_415, size = 52.4 Gb, run-time = 14.910961 (sec.)
# sleep( 1 )
#
# idx = [1]
# cpu float64(8 bytes)
# free_mem_bytes = 165_373_886_464 bytes 98%%
# free_mem_bytes after gc= 165_371_891_712 bytes 98%%
# tick_count = 80_907, size = 52.4 Gb, run-time = 14.223692 (sec.)
# sleep( 1 )
#
# idx = [2]
# cpu complex64(8 bytes)
# free_mem_bytes = 165_372_100_608 bytes 98%%
# free_mem_bytes after gc= 165_363_822_592 bytes 98%%
# tick_count = 80_907, size = 52.4 Gb, run-time = 15.298391 (sec.)
# sleep( 1 )
#
# idx = [3]
# cpu complex128(16 bytes)
# free_mem_bytes = 165_363_826_688 bytes 98%%
# free_mem_bytes after gc= 165_356_081_152 bytes 98%%
# tick_count = 57_208, size = 52.4 Gb, run-time = 14.045668 (sec.)
# sleep( 1 )
#
# miny = 0, maxy = 122.0
# Result figure file = /home/machine/Zernike/result/test_030_memory_allocation_1.png
# Done.

# %%
from IPython.display import clear_output
clear_output()

from ATest_030_MemoryAlloc import *

use_gpus = [ 1 ]
operation = "*"

test_array_memory_alloc( use_gpus=use_gpus, operation=operation, debug=1 )
# Out:
# operation = *
#
# device name = cuda
# idx = [0]
# cuda int32(4 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 31_583, size = 4.0 Gb, run-time = 0.016486 (sec.)
# sleep( 1 )
#
# idx = [1]
# cuda float64(8 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 22_333, size = 4.0 Gb, run-time = 0.001555 (sec.)
# sleep( 1 )
#
# idx = [2]
# cuda complex64(8 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 22_333, size = 4.0 Gb, run-time = 0.001690 (sec.)
# sleep( 1 )
#
# idx = [3]
# cuda complex128(16 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 15_791, size = 4.0 Gb, run-time = 0.001598 (sec.)
# sleep( 1 )
#
# miny = -6.0, maxy = 36.0
# Result figure file = /home/machine/Zernike/result/test_030_memory_allocation_1.png
# Done.
