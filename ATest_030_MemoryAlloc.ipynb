# %%
from ATest_030_MemoryAlloc import *

use_gpus = [ 0 ]

test_array_memory_alloc( use_gpus=use_gpus, operation="", debug=1  )
# Out:
# operation =
#
# device name = cpu
# idx = [0]
# cpu int32(4 bytes)
# free_mem_bytes = 165_166_456_832 bytes 98%%
# free_mem_bytes after gc= 165_245_116_416 bytes 98%%
# tick_count = 198_058, size = 156.9 Gb, run-time = 13.084767 (sec.)
# sleep( 1 )
#
# idx = [1]
# cpu float64(8 bytes)
# free_mem_bytes = 165_245_325_312 bytes 98%%
# free_mem_bytes after gc= 165_194_702_848 bytes 98%%
# tick_count = 140_081, size = 157.0 Gb, run-time = 13.732887 (sec.)
# sleep( 1 )
#
# idx = [2]
# cpu complex64(8 bytes)
# free_mem_bytes = 165_194_825_728 bytes 98%%
# free_mem_bytes after gc= 165_183_631_360 bytes 98%%
# tick_count = 140_060, size = 156.9 Gb, run-time = 12.709965 (sec.)
# sleep( 1 )
#
# idx = [3]
# cpu complex128(16 bytes)
# free_mem_bytes = 165_191_475_200 bytes 98%%
# free_mem_bytes after gc= 165_181_157_376 bytes 98%%
# tick_count = 99_036, size = 156.9 Gb, run-time = 12.438700 (sec.)
# sleep( 1 )
#
# miny = 0, maxy = 220.00000000000003
# ...

# %%
from IPython.display import clear_output
clear_output()

from ATest_030_MemoryAlloc import *

use_gpus = [ 1 ]
operation = ""

test_array_memory_alloc( use_gpus=use_gpus, operation=operation, debug=1  )
# Out:
# operation =
#
# device name = cuda
# idx = [0]
# cuda int32(4 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 54_705, size = 12.0 Gb, run-time = 0.001122 (sec.)
# sleep( 1 )
#
# idx = [1]
# cuda float64(8 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 38_682, size = 12.0 Gb, run-time = 0.001056 (sec.)
# sleep( 1 )
#
# idx = [2]
# cuda complex64(8 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 38_682, size = 12.0 Gb, run-time = 0.001155 (sec.)
# sleep( 1 )
#
# idx = [3]
# cuda complex128(16 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 27_352, size = 12.0 Gb, run-time = 0.001133 (sec.)
# sleep( 1 )
#
# miny = -12.0, maxy = 62.0
# ...

# %%
from IPython.display import clear_output
clear_output()

from ATest_030_MemoryAlloc import *

use_gpus = [ 0 ]
operation = "*"

test_array_memory_alloc( use_gpus=use_gpus, operation=operation, debug=1  )
# Out:
# Hello...
#
# operation = *
#
# device name = cpu
# idx = [0]
# cpu int32(4 bytes)
# free_mem_bytes = 165_382_217_728 bytes 98%%
# free_mem_bytes after gc= 165_408_292_864 bytes 98%%
# tick_count = 114_423, size = 52.4 Gb, run-time = 15.357904 (sec.)
# sleep( 1 )
#
# idx = [1]
# cpu float64(8 bytes)
# free_mem_bytes = 165_408_141_312 bytes 98%%
# free_mem_bytes after gc= 165_454_667_776 bytes 98%%
# tick_count = 80_916, size = 52.4 Gb, run-time = 15.120957 (sec.)
# sleep( 1 )
#
# idx = [2]
# cpu complex64(8 bytes)
# free_mem_bytes = 165_454_934_016 bytes 98%%
# free_mem_bytes after gc= 165_501_689_856 bytes 98%%
# tick_count = 80_927, size = 52.4 Gb, run-time = 14.117028 (sec.)
# sleep( 1 )
#
# idx = [3]
# cpu complex128(16 bytes)
# free_mem_bytes = 165_502_152_704 bytes 98%%
# free_mem_bytes after gc= 165_500_084_224 bytes 98%%
# tick_count = 57_232, size = 52.4 Gb, run-time = 14.323051 (sec.)
# sleep( 1 )
#
# miny = 0, maxy = 122.0
# ...

# %%
from IPython.display import clear_output
clear_output()

from ATest_030_MemoryAlloc import *

use_gpus = [ 1 ]
operation = "*"

test_array_memory_alloc( use_gpus=use_gpus, operation=operation, debug=1 )
# Out:
# Hello...
#
# operation = *
#
# device name = cuda
# idx = [0]
# cuda int32(4 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 31_583, size = 4.0 Gb, run-time = 0.017157 (sec.)
# sleep( 1 )
#
# idx = [1]
# cuda float64(8 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 22_333, size = 4.0 Gb, run-time = 0.001641 (sec.)
# sleep( 1 )
#
# idx = [2]
# cuda complex64(8 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 22_333, size = 4.0 Gb, run-time = 0.001900 (sec.)
# sleep( 1 )
#
# idx = [3]
# cuda complex128(16 bytes)
# free_mem_bytes = 12_600_606_720 bytes 99%%
# free_mem_bytes after gc= 12_602_703_872 bytes 99%%
# tick_count = 15_791, size = 4.0 Gb, run-time = 0.001664 (sec.)
# sleep( 1 )
#
# miny = -6.0, maxy = 36.0
# ...
