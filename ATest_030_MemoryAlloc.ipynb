# %%
from ATest_04_MemoryAlloc import *

test_array_memory_alloc( use_gpu=0, operation="", debug=1, verbose=1 )
# Out:
# Hello...
#
# use_gpu = 0, operation =
#
# idx = [0]
# cpu int32(4 bytes)
# free_mem_bytes = 165_718_126_592 bytes 98%
# grid count = 198_388, Elapsed = 13.166144783986965, tick_count = 198_388
# free_mem_bytes after gc= 165_813_620_736 bytes 98%
# tick_count = 198_388, size = 157.4 Gb, run-time = 13.17 (sec.)
# sleep( 5 )
#
# idx = [1]
# cpu float64(8 bytes)
# free_mem_bytes = 165_811_200_000 bytes 98%
# grid count = 140_321, Elapsed = 13.101648690993898, tick_count = 140_321
# free_mem_bytes after gc= 165_851_512_832 bytes 98%
# tick_count = 140_321, size = 157.5 Gb, run-time = 13.10 (sec.)
# sleep( 5 )
#
# idx = [2]
# cpu complex64(8 bytes)
# free_mem_bytes = 165_851_824_128 bytes 98%
# grid count = 140_338, Elapsed = 13.584520558011718, tick_count = 140_338
# free_mem_bytes after gc= 165_867_429_888 bytes 98%
# tick_count = 140_338, size = 157.6 Gb, run-time = 13.58 (sec.)
# sleep( 5 )
#
# idx = [3]
# cpu complex128(16 bytes)
# free_mem_bytes = 165_866_225_664 bytes 98%
# ...

# %%
from ATest_04_MemoryAlloc import *

test_array_memory_alloc( use_gpu=1, operation="", debug=1, verbose=1 )
# Out:
# use_gpu = 1, operation =
#
# idx = [0]
# cuda int32(4 bytes)
# free_mem_bytes = 12_600_672_256 bytes 99%
# grid count = 54_705, Elapsed = 0.012484461010899395, tick_count = 54_705
# free_mem_bytes after gc= 12_602_769_408 bytes 99%
# tick_count = 54_705, size = 12.0 Gb, run-time = 0.01 (sec.)
# sleep( 5 )
#
# idx = [1]
# cuda float64(8 bytes)
# free_mem_bytes = 12_600_672_256 bytes 99%
# grid count = 38_682, Elapsed = 0.030085967999184504, tick_count = 38_682
# free_mem_bytes after gc= 12_602_769_408 bytes 99%
# tick_count = 38_682, size = 12.0 Gb, run-time = 0.03 (sec.)
# sleep( 5 )
#
# idx = [2]
# cuda complex64(8 bytes)
# free_mem_bytes = 12_600_672_256 bytes 99%
# grid count = 38_682, Elapsed = 0.0301511779834982, tick_count = 38_682
# free_mem_bytes after gc= 12_602_769_408 bytes 99%
# tick_count = 38_682, size = 12.0 Gb, run-time = 0.03 (sec.)
# sleep( 5 )
#
# idx = [3]
# cuda complex128(16 bytes)
# free_mem_bytes = 12_600_672_256 bytes 99%
# ...

# %%
from ATest_04_MemoryAlloc import *

test_array_memory_alloc( use_gpu=0, operation="*", debug=1, verbose=1 )
# Out:
# use_gpu = 0, operation = *
#
# idx = [0]
# cpu int32(4 bytes)
# free_mem_bytes = 165_483_978_752 bytes 98%
# grid count = 114_458, Elapsed = 16.899858946999302, tick_count = 114_458
# free_mem_bytes after gc= 8_060_284_928 bytes 5%
# tick_count = 114_458, size = 52.4 Gb, run-time = 16.90 (sec.)
#
# idx = [1]
# cpu int32(4 bytes)
# free_mem_bytes = 8_060_284_928 bytes 5%
# grid count = 25_260, Elapsed = 7.645317446003901, tick_count = 25_260
# free_mem_bytes after gc= 157_852_286_976 bytes 93%
# tick_count = 25_260, size = 2.6 Gb, run-time = 7.65 (sec.)
#
# idx = [2]
# cpu float64(8 bytes)
# free_mem_bytes = 157_852_286_976 bytes 93%
# grid count = 79_046, Elapsed = 13.901825524997548, tick_count = 79_046
# free_mem_bytes after gc= 15_312_109_568 bytes 9%
# tick_count = 79_046, size = 50.0 Gb, run-time = 13.90 (sec.)
#
# idx = [3]
# cpu float64(8 bytes)
# free_mem_bytes = 15_312_109_568 bytes 9%
# grid count = 24_619, Elapsed = 8.005291658002534, tick_count = 24_619
# ...

# %%
from ATest_04_MemoryAlloc import *

test_array_memory_alloc( use_gpu = 1, operation="*", debug=1, verbose=1 )
# Out:
# use_gpu = 1, operation = *
#
# idx = [0]
# cuda int32(4 bytes)
# free_mem_bytes = 12_600_672_256 bytes 99%
# grid count = 31_584, Elapsed = 0.018706506001763046, tick_count = 31_584
# free_mem_bytes after gc= 12_602_769_408 bytes 99%
# tick_count = 31_584, size = 4.0 Gb, run-time = 0.02 (sec.)
# sleep( 5 )
#
# idx = [1]
# cuda float64(8 bytes)
# free_mem_bytes = 12_600_672_256 bytes 99%
# grid count = 22_333, Elapsed = 0.02206989299156703, tick_count = 22_333
# free_mem_bytes after gc= 12_602_769_408 bytes 99%
# tick_count = 22_333, size = 4.0 Gb, run-time = 0.02 (sec.)
# sleep( 5 )
#
# idx = [2]
# cuda complex64(8 bytes)
# free_mem_bytes = 12_600_672_256 bytes 99%
# grid count = 22_333, Elapsed = 0.02068219898501411, tick_count = 22_333
# free_mem_bytes after gc= 12_602_769_408 bytes 99%
# tick_count = 22_333, size = 4.0 Gb, run-time = 0.02 (sec.)
# sleep( 5 )
#
# idx = [3]
# cuda complex128(16 bytes)
# free_mem_bytes = 12_600_672_256 bytes 99%
# ...
