# %%
from ATest_02_Devices_Compare import *

test_process_unit_spec()
# Out:
# Hello... Good morning!
# Importing python packages was done.
# Zernike functions are defined.

# %%
from ATest_02_Devices_Compare import *

test_gpu_specs_compare()
# Out:
# Hello... Good morning!
# Importing python packages was done.
# Zernike functions are defined.
#
# 2.2.0
