# %%
from ATest_070_DataSet_ImageRestore import *

plot_dataset_image_restore()
# Out:
# [000] name = lenna, channel = 1, shape=(512, 512)
# [001] name = astronaut, channel = 3, shape=(512, 512, 3)
# [002] name = camera, channel = 1, shape=(512, 512)
# [003] name = brick, channel = 1, shape=(512, 512)
# [004] name = moon, channel = 1, shape=(512, 512)
# [005] name = grass, channel = 1, shape=(512, 512)
#
# Result figure file = ./result/dataset_overview_image_restore.png
