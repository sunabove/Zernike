# %%
from ATest_050_DataSet_ZernikeMoment import *

plot_dataset_image_restore()
# Out:
# [000] name = lenna, channel = 1, shape=(512, 512)
# [001] name = astronaut, channel = 1, shape=(512, 512)
# [002] name = CameraMan, channel = 1, shape=(512, 512)
# [003] name = brick, channel = 1, shape=(512, 512)
# [004] name = moon, channel = 1, shape=(512, 512)
# [005] name = grass, channel = 1, shape=(512, 512)
# Result figure file = /home/machine/Zernike/result/atest_050_dataset_zernikemoment.png
