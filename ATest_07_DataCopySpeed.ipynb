# %%
from ATest_07_DataCopySpeed import *

Ks = torch.arange( 1, 10 + 1, 1 )
Ks = torch.arange( 3, 12 + 1, 1 )

test_data_copy_speed( Ks, debug=1 )
# Out:
# CPU : free_mem_bytes = 164_598_665_216 bytes 97%%
# GPU : free_mem_bytes = 12_602_703_872 bytes 99%%
#
# device fr = cpu, to = cuda:0, k = 3, speed = 1,561.3030 (Mb/s), size =  72.00 Mb, run_time = 0.461153 (sec.)
# device fr = cpu, to = cuda:0, k = 4, speed = 1,853.6152 (Mb/s), size = 128.00 Mb, run_time = 0.690542 (sec.)
# device fr = cpu, to = cuda:0, k = 5, speed = 1,890.5060 (Mb/s), size = 200.00 Mb, run_time = 1.057918 (sec.)
# device fr = cpu, to = cuda:0, k = 6, speed = 1,878.4884 (Mb/s), size = 288.00 Mb, run_time = 1.533148 (sec.)
# device fr = cpu, to = cuda:0, k = 7, speed = 1,888.9591 (Mb/s), size = 392.00 Mb, run_time = 2.075217 (sec.)
# device fr = cpu, to = cuda:0, k = 8, speed = 1,886.6445 (Mb/s), size = 512.00 Mb, run_time = 2.713813 (sec.)
# device fr = cpu, to = cuda:0, k = 9, speed = 1,890.8727 (Mb/s), size = 648.00 Mb, run_time = 3.426989 (sec.)
# device fr = cpu, to = cuda:0, k = 10, speed = 1,889.0045 (Mb/s), size = 800.00 Mb, run_time = 4.235035 (sec.)
# device fr = cpu, to = cuda:0, k = 11, speed = 1,891.8482 (Mb/s), size = 968.00 Mb, run_time = 5.116690 (sec.)
# device fr = cpu, to = cuda:0, k = 12, speed = 1,893.6637 (Mb/s), size = 1152.00 Mb, run_time = 6.083446 (sec.)
#
# CPU : free_mem_bytes = 164_600_377_344 bytes 97%%
# GPU : free_mem_bytes = 12_602_703_872 bytes 99%%
#
# device fr = cuda:0, to = cpu, k = 3, speed = 1,490.8892 (Mb/s), size =  72.00 Mb, run_time = 0.482933 (sec.)
# device fr = cuda:0, to = cpu, k = 4, speed = 1,514.9087 (Mb/s), size = 128.00 Mb, run_time = 0.844935 (sec.)
# device fr = cuda:0, to = cpu, k = 5, speed = 1,519.1233 (Mb/s), size = 200.00 Mb, run_time = 1.316549 (sec.)
# device fr = cuda:0, to = cpu, k = 6, speed = 1,515.5114 (Mb/s), size = 288.00 Mb, run_time = 1.900349 (sec.)
# device fr = cuda:0, to = cpu, k = 7, speed = 1,518.8122 (Mb/s), size = 392.00 Mb, run_time = 2.580964 (sec.)
# device fr = cuda:0, to = cpu, k = 8, speed = 1,521.2871 (Mb/s), size = 512.00 Mb, run_time = 3.365571 (sec.)
# device fr = cuda:0, to = cpu, k = 9, speed = 1,523.6302 (Mb/s), size = 648.00 Mb, run_time = 4.253000 (sec.)
# device fr = cuda:0, to = cpu, k = 10, speed = 1,524.1828 (Mb/s), size = 800.00 Mb, run_time = 5.248714 (sec.)
# device fr = cuda:0, to = cpu, k = 11, speed = 1,525.5929 (Mb/s), size = 968.00 Mb, run_time = 6.345074 (sec.)
# device fr = cuda:0, to = cpu, k = 12, speed = 1,526.8477 (Mb/s), size = 1152.00 Mb, run_time = 7.544957 (sec.)
#
# CPU : free_mem_bytes = 164_592_508_928 bytes 97%%
# GPU : free_mem_bytes = 12_602_703_872 bytes 99%%
#
# device fr = cuda:0, to = cuda:1, k = 3, speed = 233,828.7944 (Mb/s), size =  72.00 Mb, run_time = 0.003079 (sec.)
# device fr = cuda:0, to = cuda:1, k = 4, speed = 665,679.9901 (Mb/s), size = 128.00 Mb, run_time = 0.001923 (sec.)
# device fr = cuda:0, to = cuda:1, k = 5, speed = 563,750.5376 (Mb/s), size = 200.00 Mb, run_time = 0.003548 (sec.)
# device fr = cuda:0, to = cuda:1, k = 6, speed = 483,958.1538 (Mb/s), size = 288.00 Mb, run_time = 0.005951 (sec.)
# device fr = cuda:0, to = cuda:1, k = 7, speed = 585,800.8223 (Mb/s), size = 392.00 Mb, run_time = 0.006692 (sec.)
# device fr = cuda:0, to = cuda:1, k = 8, speed = 843,175.4871 (Mb/s), size = 512.00 Mb, run_time = 0.006072 (sec.)
# device fr = cuda:0, to = cuda:1, k = 9, speed = 1,012,105.8286 (Mb/s), size = 648.00 Mb, run_time = 0.006402 (sec.)
# device fr = cuda:0, to = cuda:1, k = 10, speed = 1,270,616.1769 (Mb/s), size = 800.00 Mb, run_time = 0.006296 (sec.)
# device fr = cuda:0, to = cuda:1, k = 11, speed = 1,507,252.5790 (Mb/s), size = 968.00 Mb, run_time = 0.006422 (sec.)
# device fr = cuda:0, to = cuda:1, k = 12, speed = 1,139,020.3456 (Mb/s), size = 1152.00 Mb, run_time = 0.010114 (sec.)
#
# Result figure file = /home/machine/Zernike/result/test_070_data_copy_speed.png
# FROM    TO            AVG         3K         4K         5K         6K         7K         8K              9K             10K             11K             12K
# ------  ------  ---------  ---------  ---------  ---------  ---------  ---------  ---------  --------------  --------------  --------------  --------------
# cpu     cuda:0    1852.49    1561.3     1853.62    1890.51    1878.49    1888.96    1886.64  1890.87         1889            1891.85         1893.66
# cuda:0  cpu       1518.08    1490.89    1514.91    1519.12    1515.51    1518.81    1521.29  1523.63         1524.18         1525.59         1526.85
# cuda:0  cuda:1  830519     233829     665680     563751     483958     585801     843175        1.01211e+06     1.27062e+06     1.50725e+06     1.13902e+06
# Excel file = /home/machine/Zernike/result/test_070_data_copy_speed.xlsx
#
# Done.
