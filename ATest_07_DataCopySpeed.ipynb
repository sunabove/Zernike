# %%
from ATest_07_DataCopySpeed import *

Ks = torch.arange( 1, 10 + 1, 1 )

test_data_copy_speed( Ks, debug=1 )
# Out:
# Hello ...
#
# CPU : free_mem_bytes = 162_571_608_064 bytes 96%%
# GPU : free_mem_bytes = 4_132_306_944 bytes 32%%
#
# device fr = cpu, to = cuda:0, k = 1, size =   8.00 Mb, run_time = 0.001173 (sec.)
# device fr = cpu, to = cuda:0, k = 2, size =  32.00 Mb, run_time = 0.004843 (sec.)
# device fr = cpu, to = cuda:0, k = 3, size =  72.00 Mb, run_time = 0.012024 (sec.)
# device fr = cpu, to = cuda:0, k = 4, size = 128.00 Mb, run_time = 0.021191 (sec.)
# device fr = cpu, to = cuda:0, k = 5, size = 200.00 Mb, run_time = 0.032908 (sec.)
# device fr = cpu, to = cuda:0, k = 6, size = 288.00 Mb, run_time = 0.047387 (sec.)
# device fr = cpu, to = cuda:0, k = 7, size = 392.00 Mb, run_time = 0.064413 (sec.)
# device fr = cpu, to = cuda:0, k = 8, size = 512.00 Mb, run_time = 0.084765 (sec.)
# device fr = cpu, to = cuda:0, k = 9, size = 648.00 Mb, run_time = 0.106078 (sec.)
# device fr = cpu, to = cuda:0, k = 10, size = 800.00 Mb, run_time = 0.130926 (sec.)
#
# ...
