# %%
from ATest_07_DataCopySpeed import *

Ks = torch.arange( 1, 10 + 1, 1 )

test_data_copy_speed( Ks, debug=1 )
# Out:
# Hello ...
#
# CPU : free_mem_bytes = 165_055_512_576 bytes 98%%
# GPU : free_mem_bytes = 12_619_481_088 bytes 99%%
#
# device fr = cpu, to = cuda:0, k = 1, speed = 6,885.0789 (Mb/s), size =   8.00 Mb, run_time = 0.011619 (sec.)
# device fr = cpu, to = cuda:0, k = 2, speed = 6,581.9461 (Mb/s), size =  32.00 Mb, run_time = 0.048618 (sec.)
# device fr = cpu, to = cuda:0, k = 3, speed = 6,774.2330 (Mb/s), size =  72.00 Mb, run_time = 0.106285 (sec.)
# device fr = cpu, to = cuda:0, k = 4, speed = 6,828.6985 (Mb/s), size = 128.00 Mb, run_time = 0.187444 (sec.)
# device fr = cpu, to = cuda:0, k = 5, speed = 6,838.2195 (Mb/s), size = 200.00 Mb, run_time = 0.292474 (sec.)
# device fr = cpu, to = cuda:0, k = 6, speed = 6,877.8579 (Mb/s), size = 288.00 Mb, run_time = 0.418735 (sec.)
# device fr = cpu, to = cuda:0, k = 7, speed = 6,882.0414 (Mb/s), size = 392.00 Mb, run_time = 0.569598 (sec.)
# ...
