# %%
# 저니크 피라미드 생성 검증 

from ATest_10_Zernike_Pyramid import *  

use_gpu = 1
debug = 0

col_cnt = 5 # 4
row_cnt = 5 # 4 6 7

circle_type = "inner"
img_type = "real"
# Out:
# Hello... Good morning!
#
# Packages imported.
# Zernike functions are defined.

# %%
# 저니크 피라미드 생성 검증 

from ATest_10_Zernike_Pyramid import *  

use_gpu = 1
debug = 0


col_cnt = 5 # 4
row_cnt = 5 # 4 6 7

circle_type = "inner"
img_type = "real"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_gpu=use_gpu, debug=debug )
# Out:
# Current Time = 11:52:33
#
# Zernike Pyramid Creation Validation
#
# use_gpu = 1, circle_type = inner, resolution = 2_000
# p =   0, q =   0, img type = real
# p =   1, q =  -1, img type = real
# p =   1, q =   1, img type = real
# p =   2, q =  -2, img type = real
# p =   2, q =   0, img type = real
# p =   2, q =   2, img type = real
# p =   3, q =  -3, img type = real
# p =   3, q =  -1, img type = real
# p =   3, q =   1, img type = real
# p =   3, q =   3, img type = real
# p =   4, q =  -4, img type = real
# p =   4, q =  -2, img type = real
# p =   4, q =   0, img type = real
# p =   4, q =   2, img type = real
# p =   4, q =   4, img type = real
# p =   5, q =  -5, img type = real
# p =   5, q =  -3, img type = real
# p =   5, q =  -1, img type = real
# p =   5, q =   1, img type = real
# p =   5, q =   3, img type = real
# p =   5, q =   5, img type = real
# p =   6, q =  -6, img type = real
# p =   6, q =  -4, img type = real
# p =   6, q =  -2, img type = real
# ...

# %%
circle_type = "inner"
img_type = "img"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_gpu=use_gpu, debug=debug )
# Out:
# Current Time = 11:53:57
#
# Zernike Pyramid Creation Validation
#
# use_gpu = 1, circle_type = inner, resolution = 2_000
# p =   0, q =   0, img type = img
# p =   1, q =  -1, img type = img
# p =   1, q =   1, img type = img
# p =   2, q =  -2, img type = img
# p =   2, q =   0, img type = img
# p =   2, q =   2, img type = img
# p =   3, q =  -3, img type = img
# p =   3, q =  -1, img type = img
# p =   3, q =   1, img type = img
# p =   3, q =   3, img type = img
# p =   4, q =  -4, img type = img
# p =   4, q =  -2, img type = img
# p =   4, q =   0, img type = img
# p =   4, q =   2, img type = img
# p =   4, q =   4, img type = img
# p =   5, q =  -5, img type = img
# p =   5, q =  -3, img type = img
# p =   5, q =  -1, img type = img
# p =   5, q =   1, img type = img
# p =   5, q =   3, img type = img
# p =   5, q =   5, img type = img
# p =   6, q =  -6, img type = img
# p =   6, q =  -4, img type = img
# p =   6, q =  -2, img type = img
# p =   6, q =   0, img type = img
#
# ...

# %%
circle_type = "inner"
img_type = "abs"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_gpu=use_gpu, debug=debug )
# Out:
# Current Time = 11:56:37
#
# Zernike Pyramid Creation Validation
#
# use_gpu = 1, circle_type = inner, resolution = 2_000
# p =   0, q =   0, img type = abs
# p =   1, q =  -1, img type = abs
# p =   1, q =   1, img type = abs
# p =   2, q =  -2, img type = abs
# p =   2, q =   0, img type = abs
# p =   2, q =   2, img type = abs
# p =   3, q =  -3, img type = abs
# p =   3, q =  -1, img type = abs
# p =   3, q =   1, img type = abs
# p =   3, q =   3, img type = abs
# p =   4, q =  -4, img type = abs
# p =   4, q =  -2, img type = abs
# p =   4, q =   0, img type = abs
# p =   4, q =   2, img type = abs
# p =   4, q =   4, img type = abs
# p =   5, q =  -5, img type = abs
# p =   5, q =  -3, img type = abs
# p =   5, q =  -1, img type = abs
# p =   5, q =   1, img type = abs
# p =   5, q =   3, img type = abs
# p =   5, q =   5, img type = abs
# p =   6, q =  -6, img type = abs
# p =   6, q =  -4, img type = abs
# p =   6, q =  -2, img type = abs
# p =   6, q =   0, img type = abs
#
# ...

# %%
circle_type = "outer"
img_type = "real"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_gpu=use_gpu, debug=debug )
# Out:
# Current Time = 11:59:07
#
# Zernike Pyramid Creation Validation
#
# use_gpu = 1, circle_type = outer, resolution = 2_000
# p =   0, q =   0, img type = real
# p =   1, q =  -1, img type = real
# p =   1, q =   1, img type = real
# p =   2, q =  -2, img type = real
# p =   2, q =   0, img type = real
# p =   2, q =   2, img type = real
# p =   3, q =  -3, img type = real
# p =   3, q =  -1, img type = real
# p =   3, q =   1, img type = real
# p =   3, q =   3, img type = real
# p =   4, q =  -4, img type = real
# p =   4, q =  -2, img type = real
# p =   4, q =   0, img type = real
# p =   4, q =   2, img type = real
# p =   4, q =   4, img type = real
# p =   5, q =  -5, img type = real
# p =   5, q =  -3, img type = real
# p =   5, q =  -1, img type = real
# p =   5, q =   1, img type = real
# p =   5, q =   3, img type = real
# p =   5, q =   5, img type = real
# p =   6, q =  -6, img type = real
# p =   6, q =  -4, img type = real
# p =   6, q =  -2, img type = real
# ...

# %%
circle_type = "outer"
img_type = "img"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_gpu=use_gpu, debug=debug )
# Out:
# Current Time = 12:00:12
#
# Zernike Pyramid Creation Validation
#
# use_gpu = 1, circle_type = outer, resolution = 2_000
# p =   0, q =   0, img type = img
# p =   1, q =  -1, img type = img
# p =   1, q =   1, img type = img
# p =   2, q =  -2, img type = img
# p =   2, q =   0, img type = img
# p =   2, q =   2, img type = img
# p =   3, q =  -3, img type = img
# p =   3, q =  -1, img type = img
# p =   3, q =   1, img type = img
# p =   3, q =   3, img type = img
# p =   4, q =  -4, img type = img
# p =   4, q =  -2, img type = img
# p =   4, q =   0, img type = img
# p =   4, q =   2, img type = img
# p =   4, q =   4, img type = img
# p =   5, q =  -5, img type = img
# p =   5, q =  -3, img type = img
# p =   5, q =  -1, img type = img
# p =   5, q =   1, img type = img
# p =   5, q =   3, img type = img
# p =   5, q =   5, img type = img
# p =   6, q =  -6, img type = img
# p =   6, q =  -4, img type = img
# p =   6, q =  -2, img type = img
# p =   6, q =   0, img type = img
#
# ...

# %%
circle_type = "outer"
img_type = "abs"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_gpu=use_gpu, debug=debug )
# Out:
# Current Time = 12:02:48
#
# Zernike Pyramid Creation Validation
#
# use_gpu = 1, circle_type = outer, resolution = 2_000
# p =   0, q =   0, img type = abs
# p =   1, q =  -1, img type = abs
# p =   1, q =   1, img type = abs
# p =   2, q =  -2, img type = abs
# p =   2, q =   0, img type = abs
# p =   2, q =   2, img type = abs
# p =   3, q =  -3, img type = abs
# p =   3, q =  -1, img type = abs
# p =   3, q =   1, img type = abs
# p =   3, q =   3, img type = abs
# p =   4, q =  -4, img type = abs
# p =   4, q =  -2, img type = abs
# p =   4, q =   0, img type = abs
# p =   4, q =   2, img type = abs
# p =   4, q =   4, img type = abs
# p =   5, q =  -5, img type = abs
# p =   5, q =  -3, img type = abs
# p =   5, q =  -1, img type = abs
# p =   5, q =   1, img type = abs
# p =   5, q =   3, img type = abs
# p =   5, q =   5, img type = abs
# p =   6, q =  -6, img type = abs
# p =   6, q =  -4, img type = abs
# p =   6, q =  -2, img type = abs
# p =   6, q =   0, img type = abs
#
# ...
