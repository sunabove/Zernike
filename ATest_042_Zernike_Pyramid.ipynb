# %%
# 저니크 피라미드 생성 검증 
from IPython.display import clear_output
clear_output()

from ATest_042_Zernike_Pyramid import *  

use_gpu = 1
debug = 1

col_cnt = 5 # 4
row_cnt = 5 # 4 6 7

circle_type = "inner"
img_type = "real"

use_cache = 1

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_cache=use_cache, use_gpu=use_gpu, debug=debug )
# Out:
# Hello... Good morning!
#
# Packages imported.
# Zernike functions are defined.
#
# Current Time = 13:45:50
#
# Zernike Pyramid Creation Validation
#
# --- Loading vpq cache P = 10, MaxK = 2, circle_type = inner, device = cuda:0
# --- [01.5%] zernike cache load FILE => cuda:1 : /home/machine/Zernike/pyramid/v_torch.complex64_inner_R2000_P00_Q00.pth : resolution = 2000, p =   0, q =   0
# --- [03.0%] zernike cache load FILE => cuda:2 : /home/machine/Zernike/pyramid/v_torch.complex64_inner_R2000_P01_Q01.pth : resolution = 2000, p =   1, q =   1
# --- [06.1%] zernike cache load FILE => cuda:3 : /home/machine/Zernike/pyramid/v_torch.complex64_inner_R2000_P02_Q02.pth : resolution = 2000, p =   2, q =   2
# --- [07.6%] zernike cache load FILE => cuda:1 : /home/machine/Zernike/pyramid/v_torch.complex64_inner_R2000_P02_Q00.pth : resolution = 2000, p =   2, q =   0
# ...

# %%
from IPython.display import clear_output
clear_output()

debutg = 0
circle_type = "inner"
img_type = "img"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_cache=use_cache, use_gpu=use_gpu, debug=debug )
# Out:
# Current Time = 13:46:16
#
# Zernike Pyramid Creation Validation
#
# --- Loading vpq cache P = 10, MaxK = 2, circle_type = inner, device = cuda:0
# --- [01.5%] zernike cache load FILE => cuda:2 : /home/machine/Zernike/pyramid/v_torch.complex64_inner_R2000_P00_Q00.pth : resolution = 2000, p =   0, q =   0
# --- [03.0%] zernike cache load FILE => cuda:2 : /home/machine/Zernike/pyramid/v_torch.complex64_inner_R2000_P01_Q01.pth : resolution = 2000, p =   1, q =   1
# --- [06.1%] zernike cache load FILE => cuda:2 : /home/machine/Zernike/pyramid/v_torch.complex64_inner_R2000_P02_Q02.pth : resolution = 2000, p =   2, q =   2
# --- [07.6%] zernike cache load FILE => cuda:2 : /home/machine/Zernike/pyramid/v_torch.complex64_inner_R2000_P02_Q00.pth : resolution = 2000, p =   2, q =   0
# --- [10.6%] zernike cache load FILE => cuda:2 : /home/machine/Zernike/pyramid/v_torch.complex64_inner_R2000_P03_Q03.pth : resolution = 2000, p =   3, q =   3
# ...

# %%
from IPython.display import clear_output
clear_output()

circle_type = "inner"
img_type = "abs"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_gpu=use_gpu, use_cache=1, debug=debug )
# Out:
# Current Time = 12:21:06
#
# Zernike Pyramid Creation Validation
#
# --- Loading vpq cache P = 10, MaxK = 2, circle_type = inner, device = cuda:0
# --- [01.5%] zernike cache load FILE => cuda:2 : /home/machine/Zernike/pyramid/v_inner_R2000_P00_Q00.pth : resolution = 2000, p =   0, q =   0
# --- [03.0%] zernike cache load FILE => cuda:2 : /home/machine/Zernike/pyramid/v_inner_R2000_P01_Q01.pth : resolution = 2000, p =   1, q =   1
# --- [06.1%] zernike cache load FILE => cuda:2 : /home/machine/Zernike/pyramid/v_inner_R2000_P02_Q02.pth : resolution = 2000, p =   2, q =   2
# --- [07.6%] zernike cache load FILE => cuda:2 : /home/machine/Zernike/pyramid/v_inner_R2000_P02_Q00.pth : resolution = 2000, p =   2, q =   0
# --- [10.6%] zernike cache load FILE => cuda:2 : /home/machine/Zernike/pyramid/v_inner_R2000_P03_Q03.pth : resolution = 2000, p =   3, q =   3
# ...

# %%
from IPython.display import clear_output
clear_output()

circle_type = "outer"
img_type = "real"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_gpu=use_gpu, use_cache=1, debug=debug )
# Out:
# Current Time = 12:10:54
#
# Zernike Pyramid Creation Validation
#
# use_gpu = 1, circle_type = outer, K = 2, cache = True
# p =   0, q =   0, img type = real
# zernike cache file save = /home/machine/Zernike/pyramid/v_outer_R002000_P+00_Q+00.pt
# p =   1, q =  -1, img type = real
# zernike cache file save = /home/machine/Zernike/pyramid/v_outer_R002000_P+01_Q+01.pt
# zernike cache file save = /home/machine/Zernike/pyramid/v_outer_R002000_P+01_Q-01.pt
# p =   1, q =   1, img type = real
# p =   2, q =  -2, img type = real
# zernike cache file save = /home/machine/Zernike/pyramid/v_outer_R002000_P+02_Q+02.pt
# zernike cache file save = /home/machine/Zernike/pyramid/v_outer_R002000_P+02_Q-02.pt
# p =   2, q =   0, img type = real
# zernike cache file save = /home/machine/Zernike/pyramid/v_outer_R002000_P+02_Q+00.pt
# p =   2, q =   2, img type = real
# p =   3, q =  -3, img type = real
# zernike cache file save = /home/machine/Zernike/pyramid/v_outer_R002000_P+03_Q+03.pt
# ...

# %%
from IPython.display import clear_output
clear_output()

circle_type = "outer"
img_type = "img"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_gpu=use_gpu, use_cache=1, debug=debug )
# Out:
# Current Time = 12:11:26
#
# Zernike Pyramid Creation Validation
#
# use_gpu = 1, circle_type = outer, K = 2, cache = True
# p =   0, q =   0, img type = img
# zernike cache file load = /home/machine/Zernike/pyramid/v_outer_R002000_P+00_Q+00.pt
# p =   1, q =  -1, img type = img
# zernike cache file load = /home/machine/Zernike/pyramid/v_outer_R002000_P+01_Q-01.pt
# p =   1, q =   1, img type = img
# zernike cache file load = /home/machine/Zernike/pyramid/v_outer_R002000_P+01_Q+01.pt
# p =   2, q =  -2, img type = img
# zernike cache file load = /home/machine/Zernike/pyramid/v_outer_R002000_P+02_Q-02.pt
# p =   2, q =   0, img type = img
# zernike cache file load = /home/machine/Zernike/pyramid/v_outer_R002000_P+02_Q+00.pt
# p =   2, q =   2, img type = img
# zernike cache file load = /home/machine/Zernike/pyramid/v_outer_R002000_P+02_Q+02.pt
# p =   3, q =  -3, img type = img
# zernike cache file load = /home/machine/Zernike/pyramid/v_outer_R002000_P+03_Q-03.pt
# ...

# %%
from IPython.display import clear_output
clear_output()

circle_type = "outer"
img_type = "abs"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_gpu=use_gpu, use_cache=1, debug=debug )
# Out:
# Current Time = 12:11:52
#
# Zernike Pyramid Creation Validation
#
# use_gpu = 1, circle_type = outer, K = 2, cache = True
# p =   0, q =   0, img type = abs
# zernike cache file load = /home/machine/Zernike/pyramid/v_outer_R002000_P+00_Q+00.pt
# p =   1, q =  -1, img type = abs
# zernike cache file load = /home/machine/Zernike/pyramid/v_outer_R002000_P+01_Q-01.pt
# p =   1, q =   1, img type = abs
# zernike cache file load = /home/machine/Zernike/pyramid/v_outer_R002000_P+01_Q+01.pt
# p =   2, q =  -2, img type = abs
# zernike cache file load = /home/machine/Zernike/pyramid/v_outer_R002000_P+02_Q-02.pt
# p =   2, q =   0, img type = abs
# zernike cache file load = /home/machine/Zernike/pyramid/v_outer_R002000_P+02_Q+00.pt
# p =   2, q =   2, img type = abs
# zernike cache file load = /home/machine/Zernike/pyramid/v_outer_R002000_P+02_Q+02.pt
# p =   3, q =  -3, img type = abs
# zernike cache file load = /home/machine/Zernike/pyramid/v_outer_R002000_P+03_Q-03.pt
# ...
