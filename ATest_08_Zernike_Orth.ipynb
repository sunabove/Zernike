# %%
print( "Plots of Radial Poolynomial" )

from ATest_08_Zernike_Orth import *

test_radial_function_validation()

print( "Done.")
# Out:
# Plots of Radial Poolynomial
# Hello... Good morning!
#
# Packages imported.
# Zernike functions are defined.
# use_gpu = 1, device_no = 0
# Done.

# %%
# Zernike Radial polynomial orthogonality validation

from ATest_08_Zernike_Orth import *

P = 10 # 40 #6 #10 # 20
Ks = torch.arange( 1, 6 + 1, 1 )

validte_radial_function_ortho( P, Ks, debug=0 )
# Out:
# Current Time = 12:21:08
#
# Zernike Radial polynomial orthogonality validation
# K:   0%|          | 0/6 [00:00<?, ?it/s]
# K: 100%|██████████| 6/6 [02:16<00:00, 22.73s/it]
# K: 100%|██████████| 6/6 [07:45<00:00, 77.63s/it]
# result_figure_file = /home/machine/Zernike/result/zernike_02_radial_orthogonality.png
# Device    Item             1K           2K           3K           4K           5K           6K
# --------  ------  -----------  -----------  -----------  -----------  -----------  -----------
# CPU       Error   2.2536e-06   5.63717e-07  2.50578e-07  1.4095e-07   9.02018e-08  6.26424e-08
# GPU       Error   2.25339e-06  5.63725e-07  2.5059e-07   1.40956e-07  9.02066e-08  6.26454e-08
#
# Current Time = 12:31:11

# %%
# 저니크 함수 직교성 테스트 

from ATest_08_Zernike_Orth import *

print( "\nZernike function orthogonality validation" )

Ks = torch.arange( 1, 3 + 1, 1 )

Ps = torch.arange( 5, 10 + 1, 5 )
Ks = torch.arange( 1, 2 + 1, 1 )

Ps = torch.arange( 5, 10 + 1, 5 )
Ks = torch.arange( 1, 6 + 1, 1 )

Ps = torch.arange( 5, 30 + 1, 5 )
Ks = torch.arange( 1, 6 + 1, 1 )

use_gpus = [ 1, 0 ] 
debug = 0

test_zernike_function_ortho( Ps, Ks, use_gpus=use_gpus, debug=debug )
# Out:
# Hello... Good morning!
#
# Packages imported.
# Zernike functions are defined.
#
#
# Zernike function orthogonality validation
#
# device = GPU
# [   0 % ] GPU, P = 5, K = 1, Resolution = 1_000
# [   1 % ] Error avg. = 0.0000794582, Elapsed time = 1.6655, 0:00:01.665462
# [   1 % ] GPU, P = 5, K = 2, Resolution = 2_000
# [   2 % ] Error avg. = 0.0000285543, Elapsed time = 1.7088, 0:00:01.708831
# [   2 % ] GPU, P = 5, K = 3, Resolution = 3_000
# [   4 % ] Error avg. = 0.0000113129, Elapsed time = 2.5390, 0:00:02.538995
# [   4 % ] GPU, P = 5, K = 4, Resolution = 4_000
# [   5 % ] Error avg. = 0.0000078351, Elapsed time = 3.7049, 0:00:03.704867
# [   5 % ] GPU, P = 5, K = 5, Resolution = 5_000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 21
#      18 use_gpus = [ 1, 0 ]
#      19 debug = 0
# ---> 21 test_zernike_function_ortho( Ps, Ks, use_gpus=use_gpus, debug=debug )
#
# File ~/Zernike/ATest_08_Zernike_Orth.py:309, in test_zernike_function_ortho(Ps, Ks, use_gpus, debug)
#     307 for m in range( -n, n + 1, 2 ) :
#     308     v_pl = Vpq( p, q, rho, theta, device=device, debug=debug )
# --> 309     v_ql = Vpq( n, m, rho, theta, device=device, debug=debug )
#     311     sum_arr = torch.sum( torch.conj(v_pl)*v_ql )
#     312     sum_integration = sum_arr*dx*dy*(p +1)/pi
#
# File ~/Zernike/AZernike.py:207, in Vpq(p, q, rho, theta, device, debug)
#     204 v_pq = None
#     206 if q < 0 :
# --> 207     v_pq = Vpq( p, abs(q), rho, theta, device=device, debug=debug )
#     209     v_pq = torch.conj( v_pq )
#     210 else :
#
# File ~/Zernike/AZernike.py:211, in Vpq(p, q, rho, theta, device, debug)
#     209     v_pq = torch.conj( v_pq )
#     210 else :
# --> 211     r_pq = Rpq( p, q, rho, device=device, debug=debug )
#     213     if q :
#     214         v_pq = r_pq*torch.exp( (1j*q)*theta )
#
# File ~/Zernike/AZernike.py:170, in Rpq(p, q, rho, device, debug)
#     168     r_pq_rho = rho*rho
#     169 else :
# --> 170     R_ps, k = _pqs_facotrial( p, q, device=device )
#     172     for r_ps, p_2s in zip( R_ps, p - 2*k ) :
#     173         rps = _rps( r_ps, rho, p_2s, debug=debug )
#
# File ~/Zernike/AZernike.py:77, in _pqs_facotrial(p, q, device)
#      74 use_torch = 1
#      76 if use_torch :
# ---> 77     return _pqs_facotrial_torch( p, q, device )
#      78 else :
#      79     return _pqs_facotrial_numpy( p, q, device )
#
# File ~/Zernike/AZernike.py:91, in _pqs_facotrial_torch(p, q, device)
#      89 fact = factorial( p - k )
#      90 fact1 = fact/factorial( k )
# ---> 91 fact2 = fact1/factorial( (p + q)/2 - k )
#      92 fact3 = fact2/factorial( (p - q)/2 - k )
#      94 R_ps = torch.pow( -1, k )*( fact3 )
#
# File ~/Zernike/AZernike.py:61, in factorial(n)
#      58     v[ torch.where( v.isinf() ) ] = 0
#      60     if torch.isnan( v ).any() : print( "torch factorial() : nan encountered" ); print( f"n = {n}")
# ---> 61     if torch.isinf( v ).any() : print( "torch factorial() : inf encountered" ); print( f"n = {n}")
#      62 else :
#      63     v = scipy.special.factorial( n )
#
# KeyboardInterrupt:
