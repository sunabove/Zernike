# %%
from AZernike import *
# Out:
# Hello... Good morning!
# Importing python packages was done.
# Zernike functions are defined.

# %%
# cpu, gpu info
print_cpu_info()
print()
print_gpu_info()
# Out:
# **************************** CPU Details *****************************
# Processor type: x86_64
# Operating system release: 6.5.0-17-generic
# Operating system version: #17-Ubuntu SMP PREEMPT_DYNAMIC Thu Jan 11 14:01:59 UTC 2024
#
# Number of physical cores: 8
# Number of logical cores: 16
# Current CPU frequency: 1.23 GHz
# Min CPU frequency: 1.2 GHz
# Max CPU frequency: 3.5 GHz
#
# *************************** Memory Details ***************************
# Total RAM installed: 168.86 GB
# Available RAM: 164.72 GB
# Used RAM: 2.93 GB
# RAM usage: 2.4%
#
# **************************** GPU Details *****************************
#   id  name             load    free memory    used memory    total memory    temperature
# ----  ---------------  ------  -------------  -------------  --------------  -------------
#    0  NVIDIA TITAN Xp  0.0%    12.183 GB      0.006 GB       12.288 GB       16.0 °C
#    1  NVIDIA TITAN Xp  0.0%    12.183 GB      0.006 GB       12.288 GB       21.0 °C
# ...

# %%
from ATest_08_Zernike_Orth import *

test_process_unit_spec()
# Out:
# Hello... Good morning!
# Importing python packages was done.
# Zernike functions are defined.

# %%
print( "Plots of Radial Poolynomial" )
print_curr_time()

from ATest_08_Zernike_Orth import *

test_radial_function_validation()

print( "Done.")
# Out:
# Plots of Radial Poolynomial
# Current Time = 20:50:12
# use_gpu = 1, device_no = 0
# Done.

# %%
# Zernike Radial polynomial orthogonality validation

from ATest_08_Zernike_Orth import *

T = 40 # 40 #6 #10 # 20

validte_radial_polynomial_ortho( T, debug=1 )
# Out:
# Hello... Good morning!
# Importing python packages was done.
# Zernike functions are defined.
#
# Current Time = 18:45:28
#
# Zernike Radial polynomial orthogonality validation
# Resolution:  20%|██        | 1/5 [00:09<00:37,  9.38s/it]
# ******************************************************************************************
# device = cpu, Radial Grid Count = 1_024, T = 40, rho_len = 1_024
# Elapsed time = 9.384, Error average = 0.00016064
# Resolution:  40%|████      | 2/5 [00:19<00:29,  9.87s/it]
# ******************************************************************************************
# device = cpu, Radial Grid Count = 2_048, T = 40, rho_len = 2_048
# Elapsed time = 10.201, Error average = 0.00007499
# Resolution:  60%|██████    | 3/5 [00:31<00:21, 10.61s/it]
# ******************************************************************************************
# device = cpu, Radial Grid Count = 4_096, T = 40, rho_len = 4_096
# Elapsed time = 11.502, Error average = 0.00003629
# ...

# %%
# 저니크 함수 직교성 테스트 

from ATest_08_Zernike_Orth import *

print_curr_time()

print( "\nZernike polynomail orthogonality validation" )

T = 5 #20 #4 #5 #10 # 20 
Ks = numpy.arange( 0.5, 5.5, 0.5 )
    
use_gpu = 1
use_hash = 1
test_zernike_function_ortho(T, Ks, use_gpu=use_gpu, use_hash=use_hash, debug=0)
# Out:
# Hello... Good morning!
# Importing python packages was done.
# Zernike functions are defined.
#
# Current Time = 19:25:01
#
# Zernike polynomail orthogonality validation
# use_gpu = 1, use_hash = 1
# K:   0%|          | 0/10 [00:00<?, ?it/s]
# ******************************************************************************************
# K = 0.5, Resolution = 500, T = 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      12 use_gpu = 1
#      13 use_hash = 1
# ---> 14 test_zernike_function_orthogonality(T, Ks, use_gpu=use_gpu, use_hash=use_hash, debug=0)
#
# File ~/Zernike/ATest_08_Zernike_Orth.py:321, in test_zernike_function_orthogonality(T, Ks, use_gpu, use_hash, debug)
#     318     print( f"K = {K}, Resolution = {resolution:_}, T = {T}" )
#     319 pass
# --> 321 then = perf_counter()
#     323 h = resolution
#     324 w = h
#
# ...
