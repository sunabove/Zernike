# %%
from ATest_04_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory_alloc( use_gpu=0, operation="", debug=1, verbose=1 )
# Out:
# use_gpu = 0, operation =
#
# idx = [0]
# cpu int32(4 bytes)
# free_mem_bytes = 165_493_727_232 bytes 98%
# grid count = 198_254, Elapsed = 14.116133379997336, tick_count = 198_254
# free_mem_bytes after gc= 8_044_281_856 bytes 5%
# tick_count = 198_254, size = 157.2 Gb, run-time = 14.12 (sec.)
#
# idx = [1]
# cpu int32(4 bytes)
# free_mem_bytes = 8_044_281_856 bytes 5%
# grid count = 43_709, Elapsed = 8.235939527992741, tick_count = 43_709
# free_mem_bytes after gc= 157_983_920_128 bytes 94%
# tick_count = 43_709, size = 7.6 Gb, run-time = 8.24 (sec.)
#
# idx = [2]
# cpu float64(8 bytes)
# free_mem_bytes = 157_983_920_128 bytes 94%
# grid count = 136_969, Elapsed = 13.228405882007792, tick_count = 136_969
# free_mem_bytes after gc= 15_279_521_792 bytes 9%
# tick_count = 136_969, size = 150.1 Gb, run-time = 13.23 (sec.)
#
# idx = [3]
# cpu float64(8 bytes)
# free_mem_bytes = 15_279_521_792 bytes 9%
# grid count = 42_596, Elapsed = 8.481802309994237, tick_count = 42_596
# free_mem_bytes after gc= 151_092_228_096 bytes 89%
# tick_count = 42_596, size = 14.5 Gb, run-time = 8.48 (sec.)
#
# idx = [4]
# cpu complex64(8 bytes)
# free_mem_bytes = 151_092_228_096 bytes 89%
# grid count = 133_948, Elapsed = 12.405436795001151, tick_count = 133_948
# free_mem_bytes after gc= 21_840_781_312 bytes 13%
# tick_count = 133_948, size = 143.5 Gb, run-time = 12.41 (sec.)
#
# idx = [5]
# cpu complex64(8 bytes)
# free_mem_bytes = 21_840_781_312 bytes 13%
# grid count = 50_927, Elapsed = 8.913420204000431, tick_count = 50_927
# free_mem_bytes after gc= 144_841_924_608 bytes 86%
# tick_count = 50_927, size = 20.7 Gb, run-time = 8.91 (sec.)
#
# idx = [6]
# cpu complex128(16 bytes)
# free_mem_bytes = 144_841_924_608 bytes 86%
# grid count = 92_736, Elapsed = 11.87281959601387, tick_count = 92_736
# free_mem_bytes after gc= 27_780_030_464 bytes 16%
# tick_count = 92_736, size = 137.6 Gb, run-time = 11.87 (sec.)
#
# idx = [7]
# cpu complex128(16 bytes)
# free_mem_bytes = 27_779_801_088 bytes 16%
# grid count = 40_613, Elapsed = 9.396039155995823, tick_count = 40_613
# free_mem_bytes after gc= 139_191_230_464 bytes 82%
# tick_count = 40_613, size = 26.4 Gb, run-time = 9.40 (sec.)
# Done.

# %%
from ATest_04_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory_alloc( use_gpu=1, operation="", debug=1, verbose=1 )
# Out:
# use_gpu = 1, operation =
#
# idx = [0]
# cuda int32(4 bytes)
# free_mem_bytes = 6_726_549_504 bytes 53%
# grid count = 39_969, Elapsed = 0.0260563220072072, tick_count = 39_969
# free_mem_bytes after gc= 6_208_552_960 bytes 49%
# tick_count = 39_969, size = 6.4 Gb, run-time = 0.03 (sec.)
#
# idx = [1]
# cuda int32(4 bytes)
# free_mem_bytes = 6_208_552_960 bytes 49%
# grid count = 38_399, Elapsed = 0.09140624500287231, tick_count = 38_399
# free_mem_bytes after gc= 6_701_383_680 bytes 52%
# tick_count = 38_399, size = 5.9 Gb, run-time = 0.09 (sec.)
#
# idx = [2]
# cuda float64(8 bytes)
# free_mem_bytes = 6_701_383_680 bytes 52%
# grid count = 28_209, Elapsed = 0.07543990299745928, tick_count = 28_209
# free_mem_bytes after gc= 6_233_718_784 bytes 49%
# tick_count = 28_209, size = 6.4 Gb, run-time = 0.08 (sec.)
#
# idx = [3]
# cuda float64(8 bytes)
# free_mem_bytes = 6_233_718_784 bytes 49%
# grid count = 27_207, Elapsed = 0.0822930290014483, tick_count = 27_207
# free_mem_bytes after gc= 6_678_315_008 bytes 52%
# tick_count = 27_207, size = 5.9 Gb, run-time = 0.08 (sec.)
#
# idx = [4]
# cuda complex64(8 bytes)
# free_mem_bytes = 6_678_315_008 bytes 52%
# grid count = 28_161, Elapsed = 0.09699865400034469, tick_count = 28_161
# free_mem_bytes after gc= 6_254_690_304 bytes 49%
# tick_count = 28_161, size = 6.3 Gb, run-time = 0.10 (sec.)
#
# idx = [5]
# cuda complex64(8 bytes)
# free_mem_bytes = 6_254_690_304 bytes 49%
# grid count = 27_253, Elapsed = 0.07895204499072861, tick_count = 27_253
# free_mem_bytes after gc= 6_657_343_488 bytes 52%
# tick_count = 27_253, size = 5.9 Gb, run-time = 0.08 (sec.)
#
# idx = [6]
# cuda complex128(16 bytes)
# free_mem_bytes = 6_657_343_488 bytes 52%
# grid count = 19_881, Elapsed = 0.0880015069997171, tick_count = 19_881
# free_mem_bytes after gc= 6_275_661_824 bytes 49%
# tick_count = 19_881, size = 6.3 Gb, run-time = 0.09 (sec.)
#
# idx = [7]
# cuda complex128(16 bytes)
# free_mem_bytes = 6_275_661_824 bytes 49%
# grid count = 19_303, Elapsed = 0.07835814899590332, tick_count = 19_303
# free_mem_bytes after gc= 6_638_469_120 bytes 52%
# tick_count = 19_303, size = 6.0 Gb, run-time = 0.08 (sec.)
# Done.

# %%
from ATest_04_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory_alloc( use_gpu=0, operation="*", debug=1, verbose=1 )
# Out:
# use_gpu = 0, operation = *
#
# idx = [0]
# cpu int32(4 bytes)
# free_mem_bytes = 165_483_978_752 bytes 98%
# grid count = 114_458, Elapsed = 16.899858946999302, tick_count = 114_458
# free_mem_bytes after gc= 8_060_284_928 bytes 5%
# tick_count = 114_458, size = 52.4 Gb, run-time = 16.90 (sec.)
#
# idx = [1]
# cpu int32(4 bytes)
# free_mem_bytes = 8_060_284_928 bytes 5%
# grid count = 25_260, Elapsed = 7.645317446003901, tick_count = 25_260
# free_mem_bytes after gc= 157_852_286_976 bytes 93%
# tick_count = 25_260, size = 2.6 Gb, run-time = 7.65 (sec.)
#
# idx = [2]
# cpu float64(8 bytes)
# free_mem_bytes = 157_852_286_976 bytes 93%
# grid count = 79_046, Elapsed = 13.901825524997548, tick_count = 79_046
# free_mem_bytes after gc= 15_312_109_568 bytes 9%
# tick_count = 79_046, size = 50.0 Gb, run-time = 13.90 (sec.)
#
# idx = [3]
# cpu float64(8 bytes)
# free_mem_bytes = 15_312_109_568 bytes 9%
# grid count = 24_619, Elapsed = 8.005291658002534, tick_count = 24_619
# free_mem_bytes after gc= 150_963_748_864 bytes 89%
# tick_count = 24_619, size = 4.8 Gb, run-time = 8.01 (sec.)
#
# idx = [4]
# cpu complex64(8 bytes)
# free_mem_bytes = 150_963_748_864 bytes 89%
# grid count = 77_302, Elapsed = 13.594009798995103, tick_count = 77_302
# free_mem_bytes after gc= 21_851_209_728 bytes 13%
# tick_count = 77_302, size = 47.8 Gb, run-time = 13.59 (sec.)
#
# idx = [5]
# cpu complex64(8 bytes)
# free_mem_bytes = 21_851_918_336 bytes 13%
# grid count = 29_410, Elapsed = 8.378230525006074, tick_count = 29_410
# free_mem_bytes after gc= 144_759_287_808 bytes 86%
# tick_count = 29_410, size = 6.9 Gb, run-time = 8.38 (sec.)
#
# idx = [6]
# cpu complex128(16 bytes)
# free_mem_bytes = 144_759_287_808 bytes 86%
# grid count = 53_525, Elapsed = 13.048639018990798, tick_count = 53_525
# free_mem_bytes after gc= 27_763_511_296 bytes 16%
# tick_count = 53_525, size = 45.8 Gb, run-time = 13.05 (sec.)
#
# idx = [7]
# cpu complex128(16 bytes)
# free_mem_bytes = 27_765_575_680 bytes 16%
# grid count = 23_441, Elapsed = 8.112303641988547, tick_count = 23_441
# free_mem_bytes after gc= 139_144_769_536 bytes 82%
# tick_count = 23_441, size = 8.8 Gb, run-time = 8.11 (sec.)
# Done.

# %%
from ATest_04_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory_alloc( use_gpu = 1, operation="*", debug=1, verbose=1 )
# Out:
# Hello...
#
# use_gpu = 1, operation = *
#
# idx = [0]
# cuda int32(4 bytes)
# free_mem_bytes = 12_600_672_256 bytes 99%
# grid count = 31_584, Elapsed = 0.020354899999802, tick_count = 31_584
# free_mem_bytes after gc= 628_031_488 bytes 5%
# tick_count = 31_584, size = 4.0 Gb, run-time = 0.02 (sec.)
#
# idx = [1]
# cuda int32(4 bytes)
# free_mem_bytes = 628_031_488 bytes 5%
# grid count = 7_051, Elapsed = 0.0016998229984892532, tick_count = 7_051
# free_mem_bytes after gc= 8_410_562_560 bytes 66%
# tick_count = 7_051, size = 0.2 Gb, run-time = 0.00 (sec.)
#
# idx = [2]
# cuda float64(8 bytes)
# free_mem_bytes = 8_410_562_560 bytes 66%
# grid count = 18_246, Elapsed = 0.01013433099433314, tick_count = 18_246
# free_mem_bytes after gc= 3_283_025_920 bytes 26%
# tick_count = 18_246, size = 2.7 Gb, run-time = 0.01 (sec.)
#
# idx = [3]
# cuda float64(8 bytes)
# free_mem_bytes = 3_283_025_920 bytes 26%
# grid count = 11_399, Elapsed = 0.0013608349981950596, tick_count = 11_399
# free_mem_bytes after gc= 4_906_221_568 bytes 38%
# tick_count = 11_399, size = 1.0 Gb, run-time = 0.00 (sec.)
#
# idx = [4]
# cuda complex64(8 bytes)
# free_mem_bytes = 4_906_221_568 bytes 38%
# grid count = 13_935, Elapsed = 0.0051670140092028305, tick_count = 13_935
# free_mem_bytes after gc= 4_392_419_328 bytes 34%
# tick_count = 13_935, size = 1.6 Gb, run-time = 0.01 (sec.)
#
# idx = [5]
# cuda complex64(8 bytes)
# free_mem_bytes = 4_392_419_328 bytes 34%
# grid count = 13_185, Elapsed = 0.0015955029957694933, tick_count = 13_185
# free_mem_bytes after gc= 5_946_408_960 bytes 47%
# tick_count = 13_185, size = 1.4 Gb, run-time = 0.00 (sec.)
#
# idx = [6]
# cuda complex128(16 bytes)
# free_mem_bytes = 5_946_408_960 bytes 47%
# grid count = 10_848, Elapsed = 0.002882765998947434, tick_count = 10_848
# free_mem_bytes after gc= 4_063_166_464 bytes 32%
# tick_count = 10_848, size = 1.9 Gb, run-time = 0.00 (sec.)
#
# idx = [7]
# cuda complex128(16 bytes)
# free_mem_bytes = 4_063_166_464 bytes 32%
# grid count = 8_967, Elapsed = 0.0011198149877600372, tick_count = 8_967
# free_mem_bytes after gc= 6_726_549_504 bytes 53%
# tick_count = 8_967, size = 1.3 Gb, run-time = 0.00 (sec.)
# Done.
