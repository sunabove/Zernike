# %%
from ATest_04_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory_alloc( use_gpu=0, operation="", debug=1, verbose=1 )
# Out:
# use_gpu = 0, operation =
#
# idx = [0]
# cpu int32(4 bytes)
# free_mem_bytes = 165_482_070_016 bytes 98%
# grid count = 192_959, Elapsed = 12.613190047995886, tick_count = 192_959
# free_mem_bytes after gc= 16_787_939_328 bytes 10%
# tick_count = 192_959, size = 148.9 Gb, run-time = 12.61 (sec.)
#
# idx = [1]
# cpu int32(4 bytes)
# free_mem_bytes = 16_788_459_520 bytes 10%
# grid count = 61_460, Elapsed = 8.248786762997042, tick_count = 61_460
# free_mem_bytes after gc= 150_827_839_488 bytes 89%
# tick_count = 61_460, size = 15.1 Gb, run-time = 8.25 (sec.)
#
# idx = [2]
# cpu float64(8 bytes)
# free_mem_bytes = 150_827_839_488 bytes 89%
# grid count = 130_261, Elapsed = 10.854754641011823, tick_count = 130_261
# free_mem_bytes after gc= 29_980_282_880 bytes 18%
# tick_count = 130_261, size = 135.7 Gb, run-time = 10.85 (sec.)
#
# idx = [3]
# cpu float64(8 bytes)
# free_mem_bytes = 29_980_282_880 bytes 18%
# grid count = 58_075, Elapsed = 9.151190642005531, tick_count = 58_075
# free_mem_bytes after gc= 138_912_358_400 bytes 82%
# tick_count = 58_075, size = 27.0 Gb, run-time = 9.15 (sec.)
#
# idx = [4]
# cpu complex64(8 bytes)
# free_mem_bytes = 138_912_358_400 bytes 82%
# grid count = 125_010, Elapsed = 10.442440129001625, tick_count = 125_010
# free_mem_bytes after gc= 40_699_863_040 bytes 24%
# tick_count = 125_010, size = 125.0 Gb, run-time = 10.44 (sec.)
#
# idx = [5]
# cpu complex64(8 bytes)
# free_mem_bytes = 40_699_863_040 bytes 24%
# grid count = 67_666, Elapsed = 9.611010910986806, tick_count = 67_666
# free_mem_bytes after gc= 129_250_254_848 bytes 77%
# tick_count = 67_666, size = 36.6 Gb, run-time = 9.61 (sec.)
#
# idx = [6]
# cpu complex128(16 bytes)
# free_mem_bytes = 129_250_254_848 bytes 77%
# grid count = 85_266, Elapsed = 10.328769935003947, tick_count = 85_266
# free_mem_bytes after gc= 49_397_170_176 bytes 29%
# tick_count = 85_266, size = 116.3 Gb, run-time = 10.33 (sec.)
#
# idx = [7]
# cpu complex128(16 bytes)
# free_mem_bytes = 49_397_170_176 bytes 29%
# grid count = 52_712, Elapsed = 10.580462079000426, tick_count = 52_712
# free_mem_bytes after gc= 121_364_881_408 bytes 72%
# tick_count = 52_712, size = 44.5 Gb, run-time = 10.58 (sec.)
# Done.

# %%
from ATest_04_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory_alloc( use_gpu=1, operation="", debug=1, verbose=1 )
# Out:
# Hello...
#
# use_gpu = 1, operation =
#
# idx = [0]
# cuda int32(4 bytes)
# free_mem_bytes = 12_600_672_256 bytes 99%
# grid count = 53_246, Elapsed = 0.010260415001539513, tick_count = 53_246
# free_mem_bytes after gc= 1_259_274_240 bytes 10%
# tick_count = 53_246, size = 11.3 Gb, run-time = 0.01 (sec.)
#
# idx = [1]
# cuda int32(4 bytes)
# free_mem_bytes = 1_259_274_240 bytes 10%
# grid count = 16_832, Elapsed = 0.0013066929968772456, tick_count = 16_832
# free_mem_bytes after gc= 11_466_113_024 bytes 90%
# tick_count = 16_832, size = 1.1 Gb, run-time = 0.00 (sec.)
#
# idx = [2]
# cuda float64(8 bytes)
# free_mem_bytes = 11_466_113_024 bytes 90%
# grid count = 35_915, Elapsed = 0.2948046450037509, tick_count = 35_915
# free_mem_bytes after gc= 2_280_587_264 bytes 18%
# tick_count = 35_915, size = 10.3 Gb, run-time = 0.29 (sec.)
#
# idx = [3]
# cuda float64(8 bytes)
# free_mem_bytes = 2_280_587_264 bytes 18%
# grid count = 16_017, Elapsed = 0.002776491004624404, tick_count = 16_017
# free_mem_bytes after gc= 10_547_560_448 bytes 83%
# tick_count = 16_017, size = 2.1 Gb, run-time = 0.00 (sec.)
#
# idx = [4]
# cuda complex64(8 bytes)
# free_mem_bytes = 10_547_560_448 bytes 83%
# grid count = 34_447, Elapsed = 0.21409667099942453, tick_count = 34_447
# free_mem_bytes after gc= 3_106_865_152 bytes 24%
# tick_count = 34_447, size = 9.5 Gb, run-time = 0.21 (sec.)
#
# idx = [5]
# cuda complex64(8 bytes)
# free_mem_bytes = 3_106_865_152 bytes 24%
# grid count = 18_695, Elapsed = 0.004015229002106935, tick_count = 18_695
# free_mem_bytes after gc= 9_803_071_488 bytes 77%
# tick_count = 18_695, size = 2.8 Gb, run-time = 0.00 (sec.)
#
# idx = [6]
# cuda complex128(16 bytes)
# free_mem_bytes = 9_803_071_488 bytes 77%
# grid count = 23_482, Elapsed = 0.1973295439966023, tick_count = 23_482
# free_mem_bytes after gc= 3_777_953_792 bytes 30%
# tick_count = 23_482, size = 8.8 Gb, run-time = 0.20 (sec.)
#
# idx = [7]
# cuda complex128(16 bytes)
# free_mem_bytes = 3_777_953_792 bytes 30%
# grid count = 14_577, Elapsed = 0.009339273005025461, tick_count = 14_577
# free_mem_bytes after gc= 9_199_091_712 bytes 72%
# tick_count = 14_577, size = 3.4 Gb, run-time = 0.01 (sec.)
# Done.

# %%
from ATest_04_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory_alloc( use_gpu=0, operation="*", debug=1, verbose=1 )

# %%
test_array_memory_alloc( use_gpu = 1, operation="*", debug=1, verbose=1 )
