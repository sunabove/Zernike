# %%
from ATest_04_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory_alloc( use_gpu=0, operation="", debug=1, verbose=1 )
# Out:
# Hello...
#
#
# use_gpu = 0, operation =
#
# idx = [0]
# cpu int32(4 bytes)
# free_mem_bytes = 165_828_698_112
# grid count = 193_161, Elapsed = 11.96376740499909, tick_count = 193_161
# free_mem_bytes after del = 16_382_070_784
# tick_count = 193_161, size = 149.2 Gb, run-time = 11.96 (sec.)
#
# idx = [1]
# cpu int32(4 bytes)
# free_mem_bytes = 16_382_070_784
# grid count = 60_712, Elapsed = 8.576302371002384, tick_count = 60_712
# free_mem_bytes after del = 151_092_649_984
# tick_count = 60_712, size = 14.7 Gb, run-time = 8.58 (sec.)
#
# idx = [2]
# cpu float64(8 bytes)
# free_mem_bytes = 151_092_649_984
# grid count = 130_376, Elapsed = 10.853773316001025, tick_count = 130_376
# free_mem_bytes after del = 29_666_963_456
# tick_count = 130_376, size = 136.0 Gb, run-time = 10.85 (sec.)
#
# idx = [3]
# cpu float64(8 bytes)
# free_mem_bytes = 29_666_963_456
# grid count = 57_771, Elapsed = 9.052596068999264, tick_count = 57_771
# free_mem_bytes after del = 139_157_139_456
# tick_count = 57_771, size = 26.7 Gb, run-time = 9.05 (sec.)
#
# idx = [4]
# cpu complex64(8 bytes)
# free_mem_bytes = 139_157_139_456
# grid count = 125_120, Elapsed = 10.467846570998518, tick_count = 125_120
# free_mem_bytes after del = 40_448_397_312
# tick_count = 125_120, size = 125.2 Gb, run-time = 10.47 (sec.)
#
# idx = [5]
# cpu complex64(8 bytes)
# free_mem_bytes = 40_448_397_312
# grid count = 67_456, Elapsed = 9.578900611999416, tick_count = 67_456
# free_mem_bytes after del = 129_429_176_320
# tick_count = 67_456, size = 36.4 Gb, run-time = 9.58 (sec.)
#
# idx = [6]
# cpu complex128(16 bytes)
# free_mem_bytes = 129_429_176_320
# grid count = 85_325, Elapsed = 10.258559027999581, tick_count = 85_325
# free_mem_bytes after del = 49_203_150_848
# tick_count = 85_325, size = 116.5 Gb, run-time = 10.26 (sec.)
#
# idx = [7]
# cpu complex128(16 bytes)
# free_mem_bytes = 49_203_150_848
# grid count = 52_608, Elapsed = 9.566864952001197, tick_count = 52_608
# free_mem_bytes after del = 121_538_826_240
# tick_count = 52_608, size = 44.3 Gb, run-time = 9.57 (sec.)
# Done.

# %%
from ATest_04_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory_alloc( use_gpu=1, operation="", debug=1, verbose=1 )
# Out:
# Hello...
#
#
# use_gpu = 1, operation =
#
# idx = [0]
# cuda int32(4 bytes)
# free_mem_bytes = 12_600_672_256
# grid count = 53_246, Elapsed = 0.010008133998780977, tick_count = 53_246
# free_mem_bytes after del = 1_259_274_240
# tick_count = 53_246, size = 11.3 Gb, run-time = 0.01 (sec.)
#
# idx = [1]
# cuda int32(4 bytes)
# free_mem_bytes = 1_259_274_240
# grid count = 16_832, Elapsed = 0.001331044997641584, tick_count = 16_832
# free_mem_bytes after del = 11_466_113_024
# tick_count = 16_832, size = 1.1 Gb, run-time = 0.00 (sec.)
#
# idx = [2]
# cuda float64(8 bytes)
# free_mem_bytes = 11_466_113_024
# grid count = 35_915, Elapsed = 0.30628442899978836, tick_count = 35_915
# free_mem_bytes after del = 2_280_587_264
# tick_count = 35_915, size = 10.3 Gb, run-time = 0.31 (sec.)
#
# idx = [3]
# cuda float64(8 bytes)
# free_mem_bytes = 2_280_587_264
# grid count = 16_017, Elapsed = 0.0032906240012380295, tick_count = 16_017
# free_mem_bytes after del = 10_547_560_448
# tick_count = 16_017, size = 2.1 Gb, run-time = 0.00 (sec.)
#
# idx = [4]
# cuda complex64(8 bytes)
# free_mem_bytes = 10_547_560_448
# grid count = 34_447, Elapsed = 0.21739183400131878, tick_count = 34_447
# free_mem_bytes after del = 3_106_865_152
# tick_count = 34_447, size = 9.5 Gb, run-time = 0.22 (sec.)
#
# idx = [5]
# cuda complex64(8 bytes)
# free_mem_bytes = 3_106_865_152
# grid count = 18_695, Elapsed = 0.004456498001673026, tick_count = 18_695
# free_mem_bytes after del = 9_803_071_488
# tick_count = 18_695, size = 2.8 Gb, run-time = 0.00 (sec.)
#
# idx = [6]
# cuda complex128(16 bytes)
# free_mem_bytes = 9_803_071_488
# grid count = 23_482, Elapsed = 0.19064751800033264, tick_count = 23_482
# free_mem_bytes after del = 3_777_953_792
# tick_count = 23_482, size = 8.8 Gb, run-time = 0.19 (sec.)
#
# idx = [7]
# cuda complex128(16 bytes)
# free_mem_bytes = 3_777_953_792
# grid count = 14_577, Elapsed = 0.005596486997092143, tick_count = 14_577
# free_mem_bytes after del = 9_199_091_712
# tick_count = 14_577, size = 3.4 Gb, run-time = 0.01 (sec.)
# Done.

# %%
from ATest_04_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory_alloc( use_gpu=0, operation="*", debug=1, verbose=1 )

# %%
test_array_memory_alloc( use_gpu = 1, operation="*", debug=1, verbose=1 )
