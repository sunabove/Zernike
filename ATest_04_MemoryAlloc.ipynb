# %%
from ATest_04_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory( use_gpu=0, operation="", debug=1, verbose=1 )
# Out:
# Hello...
#
#
# use_gpu = 0, operation =
# cpu int32(4 bytes)
# free_mem_bytes = 165_951_528_960
# grid count = 203_685, Elapsed = 14.207768759002647, grid_count = 203_685
# free_mem_bytes after del = 373_848_064
# grid_count = 203_685, size = 166.0 Gb, run-time = 14.21 (sec.)
# sleep( 20 )
#
# cpu float64(8 bytes)
# free_mem_bytes = 259_231_744
# grid count = 5_692, Elapsed = 7.076201812000363, grid_count = 5_692
# free_mem_bytes after del = 166_236_528_640
# grid_count = 5_692, size = 0.3 Gb, run-time = 7.08 (sec.)
# sleep( 20 )
#
# cpu complex64(8 bytes)
# free_mem_bytes = 166_071_353_344
# grid count = 144_079, Elapsed = 14.591526066997176, grid_count = 144_079
# free_mem_bytes after del = 226_471_936
# grid_count = 144_079, size = 166.1 Gb, run-time = 14.59 (sec.)
# sleep( 20 )
#
# cpu complex128(16 bytes)
# free_mem_bytes = 298_463_232
# grid count = 4_319, Elapsed = 7.212990961001196, grid_count = 4_319
# free_mem_bytes after del = 166_374_912_000
# grid_count = 4_319, size = 0.3 Gb, run-time = 7.21 (sec.)
# sleep( 20 )
# Done.

# %%
from ATest_04_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory( use_gpu=0, operation="*", debug=1, verbose=0 )
# Out:
# Hello...
#
# max_grid_count = 90_000
#
# use_gpu = 0, operation = *
#
# int32 (4 bytes)
# zeros() received an invalid combination of arguments - got (tuple, torch.dtype), but expected one of:
#  * (tuple of ints size, *, tuple of names names, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)
#  * (tuple of ints size, *, Tensor out, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)
#
# grid_count = 257, size = 0.0 Gb, run-time = 0.00 (sec.)
#
# float64 (8 bytes)
# zeros() received an invalid combination of arguments - got (tuple, torch.dtype), but expected one of:
#  * (tuple of ints size, *, tuple of names names, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)
#  * (tuple of ints size, *, Tensor out, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)
#
# grid_count = 257, size = 0.0 Gb, run-time = 0.00 (sec.)
#
# complex64 (8 bytes)
# zeros() received an invalid combination of arguments - got (tuple, torch.dtype), but expected one of:
#  * (tuple of ints size, *, tuple of names names, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)
#  * (tuple of ints size, *, Tensor out, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)
#
# grid_count = 257, size = 0.0 Gb, run-time = 0.00 (sec.)
#
# complex128 (16 bytes)
# zeros() received an invalid combination of arguments - got (tuple, torch.dtype), but expected one of:
#  * (tuple of ints size, *, tuple of names names, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)
#  * (tuple of ints size, *, Tensor out, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)
#
# grid_count = 257, size = 0.0 Gb, run-time = 0.00 (sec.)
# Done.

# %%
from ATest_04_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory( use_gpu=1, operation="", debug=1, verbose=0 )
# Out:
# Hello...
#
#
# use_gpu = 1, operation =
# cuda int32(4 bytes)
# free_mem_bytes = 12_600_672_256
# free_mem_bytes after del = 1_259_274_240
# grid_count = 53_246, size = 11.3 Gb, run-time = 0.01 (sec.)
#
# cuda float64(8 bytes)
# free_mem_bytes = 1_259_274_240
# free_mem_bytes after del = 11_466_113_024
# grid_count = 11_902, size = 1.1 Gb, run-time = 0.00 (sec.)
#
# cuda complex64(8 bytes)
# free_mem_bytes = 11_466_113_024
# free_mem_bytes after del = 2_280_587_264
# grid_count = 35_915, size = 10.3 Gb, run-time = 0.30 (sec.)
#
# cuda complex128(16 bytes)
# free_mem_bytes = 2_280_587_264
# free_mem_bytes after del = 10_547_560_448
# grid_count = 11_326, size = 2.1 Gb, run-time = 0.00 (sec.)
# Done.

# %%
test_array_memory( use_gpu = 1, operation="*", debug=1, verbose=0 )
# Out:
# use_gpu = 1, operation = *
#
# cupy int64 (8 bytes)
# Out of memory allocating 2,147,483,648 bytes (allocated so far: 10,737,418,240 bytes).
# grid_count = 16_383, size = 2.1 Gb, run-time = 0.00 (sec.)
#
# cupy float64 (8 bytes)
# Out of memory allocating 2,147,746,304 bytes (allocated so far: 11,945,377,792 bytes).
# grid_count = 16_385, size = 3.4 Gb, run-time = 0.00 (sec.)
#
# cupy complex64 (8 bytes)
# Out of memory allocating 2,147,746,304 bytes (allocated so far: 11,945,377,792 bytes).
# grid_count = 16_385, size = 3.4 Gb, run-time = 0.00 (sec.)
#
# cupy complex128 (16 bytes)
# Out of memory allocating 1,212,153,856 bytes (allocated so far: 11,945,377,792 bytes).
# grid_count = 8_703, size = 1.2 Gb, run-time = 0.00 (sec.)
# Done.
