# %%
# 저니크 피라미드 생성 검증 
from ATest_044_Zernike_Pyramid import *  

clear_output()
torch.set_warn_always( False )
warnings.filterwarnings( "ignore" )

use_gpu = 1
debug = 0

col_cnt = 5 # 4
row_cnt = 5 # 4 6 7

circle_type = "inner"
img_type = "real"

use_cache = 1

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_cache=use_cache, use_gpu=use_gpu, debug=debug )
# Out:
# Current Time = 19:39:31
#
# Zernike Pyramid Creation Validation
#
# --- Loading vpq cache P = 10, MaxK = 2, circle_type = inner, device = cuda:0, jupyter = True
#
# --- Loading done. 5.09 (secs.) 0:00:05
# use_gpu = 1, circle_type = inner, K = 2, cache = False
# p =   0, q =   0, img type = real
# p =   1, q =  -1, img type = real
# p =   1, q =   1, img type = real
# p =   2, q =  -2, img type = real
# p =   2, q =   0, img type = real
# p =   2, q =   2, img type = real
# p =   3, q =  -3, img type = real
# p =   3, q =  -1, img type = real
# p =   3, q =   1, img type = real
# p =   3, q =   3, img type = real
# p =   4, q =  -4, img type = real
# p =   4, q =  -2, img type = real
# p =   4, q =   0, img type = real
# p =   4, q =   2, img type = real
# p =   4, q =   4, img type = real
# p =   5, q =  -3, img type = real
# p =   5, q =  -1, img type = real
# p =   5, q =   1, img type = real
# p =   5, q =   3, img type = real
# p =   6, q =  -2, img type = real
# p =   6, q =   0, img type = real
# p =   6, q =   2, img type = real
# p =   7, q =  -1, img type = real
# p =   7, q =   1, img type = real
# p =   8, q =   0, img type = real
#
# Plotting ...
# result_figure_file = /home/machine/Zernike/result/atest_044_zernike_pyramid_inner_02k_real.png

# %%
clear_output()

debutg = 0
circle_type = "inner"
img_type = "img"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_cache=use_cache, use_gpu=use_gpu, debug=debug )
# Out:
# Current Time = 18:51:16
#
# Zernike Pyramid Creation Validation
#
# --- Loading vpq cache P = 10, MaxK = 2, circle_type = inner, device = cuda:0
# /home/machine/Zernike/AZernike.py:506: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor( y, dtype=torch.float64, device=device )
# /home/machine/Zernike/AZernike.py:507: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor( x, dtype=torch.float64, device=device )
# --- [01.5%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P00_Q00.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P01_Q01.pth
# --- [04.5%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P01_Q01.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P02_Q02.pth
# --- [07.6%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P02_Q00.pth
# --- [09.1%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P02_Q02.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P03_Q03.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P03_Q01.pth
# --- [13.6%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P03_Q01.pth
# --- [15.2%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P03_Q03.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P04_Q04.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P04_Q02.pth
# --- [19.7%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P04_Q00.pth
# --- [21.2%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P04_Q02.pth
# --- [22.7%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P04_Q04.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P05_Q05.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P05_Q03.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P05_Q01.pth
# --- [28.8%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P05_Q01.pth
# --- [30.3%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P05_Q03.pth
# --- [31.8%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P05_Q05.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P06_Q06.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P06_Q04.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P06_Q02.pth
# --- [37.9%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P06_Q00.pth
# --- [39.4%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P06_Q02.pth
# --- [40.9%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P06_Q04.pth
# --- [42.4%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P06_Q06.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P07_Q07.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P07_Q05.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P07_Q03.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P07_Q01.pth
# --- [50.0%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P07_Q01.pth
# --- [51.5%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P07_Q03.pth
# --- [53.0%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P07_Q05.pth
# --- [54.5%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P07_Q07.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P08_Q08.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P08_Q06.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P08_Q04.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P08_Q02.pth
# --- [62.1%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P08_Q00.pth
# --- [63.6%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P08_Q02.pth
# --- [65.2%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P08_Q04.pth
# --- [66.7%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P08_Q06.pth
# --- [68.2%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P08_Q08.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P09_Q09.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P09_Q07.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P09_Q05.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P09_Q03.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P09_Q01.pth
# --- [77.3%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P09_Q01.pth
# --- [78.8%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P09_Q03.pth
# --- [80.3%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P09_Q05.pth
# --- [81.8%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P09_Q07.pth
# --- [83.3%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P09_Q09.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P10_Q10.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P10_Q08.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P10_Q06.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P10_Q04.pth
# ---  zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P10_Q02.pth
# --- [92.4%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P10_Q00.pth
# --- [93.9%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P10_Q02.pth
# --- [95.5%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P10_Q04.pth
# --- [97.0%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P10_Q06.pth
# --- [98.5%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P10_Q08.pth
# --- [100.0%] zernike cache file save = /home/machine/Zernike/pyramid/v_complex128_inner_R2000_P10_Q10.pth
# --- Loading done. 13.07 (secs.) 0:00:13
# use_gpu = 1, circle_type = inner, K = 2, cache = False
# p =   0, q =   0, img type = img
# p =   1, q =  -1, img type = img
# p =   1, q =   1, img type = img
# p =   2, q =  -2, img type = img
# p =   2, q =   0, img type = img
# p =   2, q =   2, img type = img
# p =   3, q =  -3, img type = img
# p =   3, q =  -1, img type = img
# p =   3, q =   1, img type = img
# p =   3, q =   3, img type = img
# p =   4, q =  -4, img type = img
# p =   4, q =  -2, img type = img
# p =   4, q =   0, img type = img
# p =   4, q =   2, img type = img
# p =   4, q =   4, img type = img
# p =   5, q =  -3, img type = img
# p =   5, q =  -1, img type = img
# p =   5, q =   1, img type = img
# p =   5, q =   3, img type = img
# p =   6, q =  -2, img type = img
# p =   6, q =   0, img type = img
# p =   6, q =   2, img type = img
# p =   7, q =  -1, img type = img
# p =   7, q =   1, img type = img
# p =   8, q =   0, img type = img
#
# Plotting ...
# result_figure_file = /home/machine/Zernike/result/atest_042_zernike_pyramid_inner_02k_img.png

# %%
from IPython.display import clear_output
clear_output()

circle_type = "inner"
img_type = "abs"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_gpu=use_gpu, use_cache=1, debug=debug )
# Out:
# Current Time = 18:53:05
#
# Zernike Pyramid Creation Validation
#
# --- Loading vpq cache P = 10, MaxK = 2, circle_type = inner, device = cuda:0
# /home/machine/Zernike/AZernike.py:506: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor( y, dtype=torch.float64, device=device )
# /home/machine/Zernike/AZernike.py:507: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor( x, dtype=torch.float64, device=device )
# --- Loading done. 12.99 (secs.) 0:00:12
# use_gpu = 1, circle_type = inner, K = 2, cache = False
# p =   0, q =   0, img type = abs
# p =   1, q =  -1, img type = abs
# p =   1, q =   1, img type = abs
# p =   2, q =  -2, img type = abs
# p =   2, q =   0, img type = abs
# p =   2, q =   2, img type = abs
# p =   3, q =  -3, img type = abs
# p =   3, q =  -1, img type = abs
# p =   3, q =   1, img type = abs
# p =   3, q =   3, img type = abs
# p =   4, q =  -4, img type = abs
# p =   4, q =  -2, img type = abs
# p =   4, q =   0, img type = abs
# p =   4, q =   2, img type = abs
# p =   4, q =   4, img type = abs
# p =   5, q =  -3, img type = abs
# p =   5, q =  -1, img type = abs
# p =   5, q =   1, img type = abs
# p =   5, q =   3, img type = abs
# p =   6, q =  -2, img type = abs
# p =   6, q =   0, img type = abs
# p =   6, q =   2, img type = abs
# p =   7, q =  -1, img type = abs
# p =   7, q =   1, img type = abs
# p =   8, q =   0, img type = abs
#
# Plotting ...
# result_figure_file = /home/machine/Zernike/result/atest_042_zernike_pyramid_inner_02k_abs.png

# %%
from IPython.display import clear_output
clear_output()

circle_type = "outer"
img_type = "real"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_gpu=use_gpu, use_cache=1, debug=debug )
# Out:
# Current Time = 18:53:35
#
# Zernike Pyramid Creation Validation
#
# --- Loading vpq cache P = 10, MaxK = 2, circle_type = outer, device = cuda:0
# /home/machine/Zernike/AZernike.py:506: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor( y, dtype=torch.float64, device=device )
# /home/machine/Zernike/AZernike.py:507: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor( x, dtype=torch.float64, device=device )
# --- Loading done. 11.89 (secs.) 0:00:11
# use_gpu = 1, circle_type = outer, K = 2, cache = False
# p =   0, q =   0, img type = real
# p =   1, q =  -1, img type = real
# p =   1, q =   1, img type = real
# p =   2, q =  -2, img type = real
# p =   2, q =   0, img type = real
# p =   2, q =   2, img type = real
# p =   3, q =  -3, img type = real
# p =   3, q =  -1, img type = real
# p =   3, q =   1, img type = real
# p =   3, q =   3, img type = real
# p =   4, q =  -4, img type = real
# p =   4, q =  -2, img type = real
# p =   4, q =   0, img type = real
# p =   4, q =   2, img type = real
# p =   4, q =   4, img type = real
# p =   5, q =  -3, img type = real
# p =   5, q =  -1, img type = real
# p =   5, q =   1, img type = real
# p =   5, q =   3, img type = real
# p =   6, q =  -2, img type = real
# p =   6, q =   0, img type = real
# p =   6, q =   2, img type = real
# p =   7, q =  -1, img type = real
# p =   7, q =   1, img type = real
# p =   8, q =   0, img type = real
#
# Plotting ...
# result_figure_file = /home/machine/Zernike/result/atest_042_zernike_pyramid_outer_02k_real.png

# %%
from IPython.display import clear_output
clear_output()

circle_type = "outer"
img_type = "img"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_gpu=use_gpu, use_cache=1, debug=debug )
# Out:
# Current Time = 18:54:04
#
# Zernike Pyramid Creation Validation
#
# --- Loading vpq cache P = 10, MaxK = 2, circle_type = outer, device = cuda:0
# /home/machine/Zernike/AZernike.py:506: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor( y, dtype=torch.float64, device=device )
# /home/machine/Zernike/AZernike.py:507: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor( x, dtype=torch.float64, device=device )
# --- Loading done. 14.73 (secs.) 0:00:14
# use_gpu = 1, circle_type = outer, K = 2, cache = False
# p =   0, q =   0, img type = img
# p =   1, q =  -1, img type = img
# p =   1, q =   1, img type = img
# p =   2, q =  -2, img type = img
# p =   2, q =   0, img type = img
# p =   2, q =   2, img type = img
# p =   3, q =  -3, img type = img
# p =   3, q =  -1, img type = img
# p =   3, q =   1, img type = img
# p =   3, q =   3, img type = img
# p =   4, q =  -4, img type = img
# p =   4, q =  -2, img type = img
# p =   4, q =   0, img type = img
# p =   4, q =   2, img type = img
# p =   4, q =   4, img type = img
# p =   5, q =  -3, img type = img
# p =   5, q =  -1, img type = img
# p =   5, q =   1, img type = img
# p =   5, q =   3, img type = img
# p =   6, q =  -2, img type = img
# p =   6, q =   0, img type = img
# p =   6, q =   2, img type = img
# p =   7, q =  -1, img type = img
# p =   7, q =   1, img type = img
# p =   8, q =   0, img type = img
#
# Plotting ...
# result_figure_file = /home/machine/Zernike/result/atest_042_zernike_pyramid_outer_02k_img.png

# %%
from IPython.display import clear_output
clear_output()

circle_type = "outer"
img_type = "abs"

test_zernike_pyramid( row_cnt, col_cnt, circle_type, img_type, use_gpu=use_gpu, use_cache=1, debug=debug )
# Out:
# Current Time = 18:54:46
#
# Zernike Pyramid Creation Validation
#
# --- Loading vpq cache P = 10, MaxK = 2, circle_type = outer, device = cuda:0
# /home/machine/Zernike/AZernike.py:506: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor( y, dtype=torch.float64, device=device )
# /home/machine/Zernike/AZernike.py:507: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor( x, dtype=torch.float64, device=device )
# --- Loading done. 14.84 (secs.) 0:00:14
# use_gpu = 1, circle_type = outer, K = 2, cache = False
# p =   0, q =   0, img type = abs
# p =   1, q =  -1, img type = abs
# p =   1, q =   1, img type = abs
# p =   2, q =  -2, img type = abs
# p =   2, q =   0, img type = abs
# p =   2, q =   2, img type = abs
# p =   3, q =  -3, img type = abs
# p =   3, q =  -1, img type = abs
# p =   3, q =   1, img type = abs
# p =   3, q =   3, img type = abs
# p =   4, q =  -4, img type = abs
# p =   4, q =  -2, img type = abs
# p =   4, q =   0, img type = abs
# p =   4, q =   2, img type = abs
# p =   4, q =   4, img type = abs
# p =   5, q =  -3, img type = abs
# p =   5, q =  -1, img type = abs
# p =   5, q =   1, img type = abs
# p =   5, q =   3, img type = abs
# p =   6, q =  -2, img type = abs
# p =   6, q =   0, img type = abs
# p =   6, q =   2, img type = abs
# p =   7, q =  -1, img type = abs
# p =   7, q =   1, img type = abs
# p =   8, q =   0, img type = abs
#
# Plotting ...
# result_figure_file = /home/machine/Zernike/result/atest_042_zernike_pyramid_outer_02k_abs.png
