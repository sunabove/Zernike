# %%
from ATest_032_MatrixMultiplication import *

device_names = [ "CPU", "GPU" ]

test_memory_multiplication_performance( device_names )
# Out:
# Device = CPU
# CPU int32(4 bytes)
# free mem = 164_724_170_752 bytes 98%
# Tick count = 114_195
# Memory alloc. = 156.49 Gb  Elapsed = 20.51 seconds
#
# Device = CPU
# CPU float64(8 bytes)
# free mem = 164_759_453_696 bytes 98%
# Tick count = 80_757
# Memory alloc. = 156.52 Gb  Elapsed = 21.05 seconds
#
# Device = CPU
# CPU complex64(8 bytes)
# free mem = 164_755_173_376 bytes 98%
# Tick count = 80_756
# Memory alloc. = 156.52 Gb  Elapsed = 20.25 seconds
#
# Device = CPU
# CPU complex128(16 bytes)
# free mem = 164_752_736_256 bytes 98%
# Tick count = 57_102
# Memory alloc. = 156.51 Gb  Elapsed = 21.64 seconds
#
# Device = GPU
# GPU int32(4 bytes)
# free mem = 12_430_737_408 bytes 97%
# Tick count = 31_370
# Memory alloc. = 11.81 Gb  Elapsed = 0.13 seconds
#
# Device = GPU
# GPU float64(8 bytes)
# free mem = 12_430_737_408 bytes 97%
# Tick count = 22_182
# Memory alloc. = 11.81 Gb  Elapsed = 0.49 seconds
#
# Device = GPU
# GPU complex64(8 bytes)
# free mem = 12_430_737_408 bytes 97%
# Tick count = 22_182
# Memory alloc. = 11.81 Gb  Elapsed = 0.43 seconds
#
# Device = GPU
# GPU complex128(16 bytes)
# free mem = 12_430_737_408 bytes 97%
# Tick count = 15_685
# Memory alloc. = 11.81 Gb  Elapsed = 0.40 seconds
#
# Result figure file = /home/machine/Zernike/result/array_multiplication_performance.png
