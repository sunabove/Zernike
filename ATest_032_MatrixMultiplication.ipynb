# %%
from ATest_06_MatrixMultiplication import *

device_names = [ "CPU", "GPU" ]

test_memory_multiplication_performance( device_names )
# Out:
# Device = CPU
# CPU int32(4 bytes)
# free mem = 165_253_447_680 bytes 98%
# Tick count = 114_379
# Memory alloc. = 156.99 Gb  Elapsed = 22.24 seconds
#
# Device = CPU
# CPU float64(8 bytes)
# free mem = 165_281_406_976 bytes 98%
# Tick count = 80_885
# Memory alloc. = 157.02 Gb  Elapsed = 21.13 seconds
#
# Device = CPU
# CPU complex64(8 bytes)
# free mem = 165_291_200_512 bytes 98%
# Tick count = 80_887
# Memory alloc. = 157.02 Gb  Elapsed = 21.55 seconds
#
# Device = CPU
# CPU complex128(16 bytes)
# free mem = 165_285_244_928 bytes 98%
# Tick count = 57_195
# Memory alloc. = 157.02 Gb  Elapsed = 21.51 seconds
#
# Device = GPU
# GPU int32(4 bytes)
# free mem = 12_600_672_256 bytes 99%
# Tick count = 31_584
# Memory alloc. = 11.97 Gb  Elapsed = 0.13 seconds
#
# Device = GPU
# GPU float64(8 bytes)
# free mem = 12_600_672_256 bytes 99%
# Tick count = 22_333
# Memory alloc. = 11.97 Gb  Elapsed = 0.49 seconds
#
# Device = GPU
# GPU complex64(8 bytes)
# free mem = 12_600_672_256 bytes 99%
# ...
