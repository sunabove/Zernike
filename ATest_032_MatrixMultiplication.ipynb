# %%
from ATest_032_MatrixMultiplication import *

device_names = [ "CPU", "GPU" ]

test_memory_multiplication_performance( device_names )
# Out:
# Device = CPU
# CPU int32(4 bytes)
# free mem = 164_911_144_960 bytes 98%
# Tick count = 114_260
# Memory alloc. = 156.66 Gb  Elapsed = 22.15 seconds
#
# Device = CPU
# CPU float64(8 bytes)
# free mem = 164_945_498_112 bytes 98%
# Tick count = 80_802
# Memory alloc. = 156.70 Gb  Elapsed = 20.25 seconds
#
# Device = CPU
# CPU complex64(8 bytes)
# free mem = 164_959_592_448 bytes 98%
# Tick count = 80_806
# Memory alloc. = 156.71 Gb  Elapsed = 20.49 seconds
#
# Device = CPU
# CPU complex128(16 bytes)
# free mem = 164_940_914_688 bytes 98%
# Tick count = 57_135
# Memory alloc. = 156.69 Gb  Elapsed = 21.72 seconds
#
# Device = GPU
# GPU int32(4 bytes)
# free mem = 12_430_737_408 bytes 97%
# Tick count = 31_370
# Memory alloc. = 11.81 Gb  Elapsed = 0.14 seconds
#
# Device = GPU
# GPU float64(8 bytes)
# free mem = 12_430_737_408 bytes 97%
# Tick count = 22_182
# Memory alloc. = 11.81 Gb  Elapsed = 0.50 seconds
#
# Device = GPU
# GPU complex64(8 bytes)
# free mem = 12_430_737_408 bytes 97%
# Tick count = 22_182
# Memory alloc. = 11.81 Gb  Elapsed = 0.46 seconds
#
# Device = GPU
# GPU complex128(16 bytes)
# free mem = 12_430_737_408 bytes 97%
# Tick count = 15_685
# Memory alloc. = 11.81 Gb  Elapsed = 0.43 seconds
#
# Result figure file = /home/machine/Zernike/result/array_multiplication_performance.png
