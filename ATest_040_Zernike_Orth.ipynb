# %%
print( "Plots of Radial Poolynomial" )

from ATest_040_Zernike_Orth import *

test_radial_polynomail_validation()

print( "Done.")
# Out:
# Plots of Radial Poolynomial
# Hello... Good morning!
#
# Packages imported.
# Zernike functions are defined.
#
# use_gpu = 1, device_no = 0
# Done.

# %%
# Zernike Radial polynomial orthogonality validation

from ATest_040_Zernike_Orth import *

P = 10 # 40 #6 #10 # 20
Ks = torch.arange( 1, 6 + 1, 1 )

validte_radial_polynomial_ortho( P, Ks, debug=0 )
# Out:
# Hello... Good morning!
#
# Packages imported.
# Zernike functions are defined.
#
# Current Time = 13:04:05
#
# Zernike Radial polynomial orthogonality validation
# ...
# K: 100%|██████████| 6/6 [00:57<00:00,  9.54s/it]
# result_figure_file = /home/machine/Zernike/result/atest_040_zernike_orth_poly_orth.png
# Device    Item             1K           2K           3K           4K           5K           6K
# --------  ------  -----------  -----------  -----------  -----------  -----------  -----------
# CPU       Error   2.2536e-06   5.63718e-07  2.50576e-07  1.40949e-07  9.02018e-08  6.26421e-08
# GPU       Error   2.25328e-06  5.63699e-07  2.50576e-07  1.40948e-07  9.02018e-08  6.26421e-08
# Excel file = /home/machine/Zernike/result/atest_040_zernike_orth_poly_orth.xlsx
#
# Current Time = 13:25:40

# %%
# 저니크 함수 직교성 테스트 

from ATest_040_Zernike_Orth import *

print( "Zernike function orthogonality validation" )

Ks = torch.arange( 1, 3 + 1, 1 )

Ps = torch.arange( 5, 10 + 1, 5 )
Ks = torch.arange( 1, 2 + 1, 1 )

Ps = torch.arange( 5, 10 + 1, 5 )
Ks = torch.arange( 1, 6 + 1, 1 )

Ps = torch.arange( 5, 30 + 1, 5 )
Ks = torch.arange( 1, 6 + 1, 1 )

use_gpus = [ 1, 0 ] 
debug = 0

test_zernike_function_ortho( Ps, Ks, use_gpus=use_gpus, debug=debug )
# Out:
# Hello... Good morning!
#
# Packages imported.
# Zernike functions are defined.
#
#
# Zernike function orthogonality validation
#
# device = GPU
# [   0 % ] GPU, P = 5, K = 1, Resolution = 1_000
# [   1 % ] Error avg. = 0.0000794582, Elapsed time = 2.1731, 0:00:02
# [   1 % ] GPU, P = 5, K = 2, Resolution = 2_000
# [   2 % ] Error avg. = 0.0000285543, Elapsed time = 2.0680, 0:00:02
# [   2 % ] GPU, P = 5, K = 3, Resolution = 3_000
# [   4 % ] Error avg. = 0.0000113129, Elapsed time = 2.9508, 0:00:02
# [   4 % ] GPU, P = 5, K = 4, Resolution = 4_000
# [   5 % ] Error avg. = 0.0000078351, Elapsed time = 4.2014, 0:00:04
# [   5 % ] GPU, P = 5, K = 5, Resolution = 5_000
# [   6 % ] Error avg. = 0.0000079266, Elapsed time = 5.8212, 0:00:05
# [   6 % ] GPU, P = 5, K = 6, Resolution = 6_000
# [   8 % ] Error avg. = 0.0000052036, Elapsed time = 7.7776, 0:00:07
# [   8 % ] GPU, P = 10, K = 1, Resolution = 1_000
# [   9 % ] Error avg. = 0.0001367201, Elapsed time = 19.7801, 0:00:19
# ...
