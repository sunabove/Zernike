# %%
from ATest_01_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory( use_gpu=0, operation="", debug=1, verbose=0 )
# Out:
# Hello...
#
# max_grid_count = 405_869
#
# use_gpu = 0, operation =
#
# numpy int32 (4 bytes)
# Unable to allocate 159. GiB for an array with shape (206764, 206764) and data type int32
# grid_count = 206_763, size = 171.0 Gb, run-time = 0.00 (sec.)
#
# numpy float64 (8 bytes)
# Unable to allocate 159. GiB for an array with shape (146204, 146204) and data type float64
# grid_count = 146_203, size = 171.0 Gb, run-time = 0.00 (sec.)
#
# numpy complex64 (8 bytes)
# Unable to allocate 159. GiB for an array with shape (146204, 146204) and data type complex64
# grid_count = 146_203, size = 171.0 Gb, run-time = 0.00 (sec.)
#
# numpy complex128 (16 bytes)
# Unable to allocate 159. GiB for an array with shape (103382, 103382) and data type complex128
# grid_count = 103_381, size = 171.0 Gb, run-time = 0.00 (sec.)
# Done.

# %%
from ATest_01_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory( use_gpu=0, operation="*", debug=1, verbose=0 )
# Out:
# Hello...
#
# max_grid_count = 90_000
#
# use_gpu = 0, operation = *
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 plt.rcParams["font.family"] = "sans-serif"
#       6 plt.rcParams["font.size"] = "16"
# ----> 8 test_array_memory( use_gpu=0, operation="*", debug=1, verbose=0 )
#
# File ~/Zernike/ATest_01_MemoryAlloc.py:48, in test_array_memory(use_gpu, operation, debug, verbose)
#      45 elapsed_times = []
#      47 for idx, data_type in enumerate( data_types ):
# ---> 48     array = np.ones( 1, data_type )
#      49     data_type_size = array.nbytes
#      51     type_str = f"{data_type}".split( " " )[-1].split(".")[-1].split( "'")[0]
#
# File /usr/local/lib/python3.11/dist-packages/torch/utils/_device.py:77, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#      75 if func in _device_constructors() and kwargs.get('device') is None:
#      76     kwargs['device'] = self.device
# ---> 77 return func(*args, **kwargs)
#
# TypeError: ones(): argument 'size' failed to unpack the object at pos 2 with error "type must be tuple of ints,but got torch.dtype"

# %%
from ATest_01_MemoryAlloc import *

from matplotlib import pyplot as plt

plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.size"] = "16"

test_array_memory( use_gpu=1, operation="", debug=1, verbose=0 )
# Out:
# Hello...
#
# max_grid_count = 404_243
#
# use_gpu = 1, operation =
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 8
#       5 plt.rcParams["font.family"] = "sans-serif"
#       6 plt.rcParams["font.size"] = "16"
# ----> 8 test_array_memory( use_gpu=1, operation="", debug=1, verbose=0 )
#
# File ~/Zernike/ATest_01_MemoryAlloc.py:37, in test_array_memory(use_gpu, operation, debug, verbose)
#      34     torch.set_default_device('cpu')
#      35 pass
# ---> 37 data_types = [ np.int_, np.double, np.csingle, np.cdouble ]
#      39 dx = 0
#      41 types = [ ]
#
# File /usr/local/lib/python3.11/dist-packages/torch/__init__.py:1932, in __getattr__(name)
#    1929     import importlib
#    1930     return importlib.import_module(f".{name}", __name__)
# -> 1932 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute 'int_'

# %%
test_array_memory( use_gpu = 1, operation="*", debug=1, verbose=0 )
# Out:
# use_gpu = 1, operation = *
#
# cupy int64 (8 bytes)
# Out of memory allocating 2,147,483,648 bytes (allocated so far: 10,737,418,240 bytes).
# grid_count = 16_383, size = 2.1 Gb, run-time = 0.00 (sec.)
#
# cupy float64 (8 bytes)
# Out of memory allocating 2,147,746,304 bytes (allocated so far: 11,945,377,792 bytes).
# grid_count = 16_385, size = 3.4 Gb, run-time = 0.00 (sec.)
#
# cupy complex64 (8 bytes)
# Out of memory allocating 2,147,746,304 bytes (allocated so far: 11,945,377,792 bytes).
# grid_count = 16_385, size = 3.4 Gb, run-time = 0.00 (sec.)
#
# cupy complex128 (16 bytes)
# Out of memory allocating 1,212,153,856 bytes (allocated so far: 11,945,377,792 bytes).
# grid_count = 8_703, size = 1.2 Gb, run-time = 0.00 (sec.)
# Done.
