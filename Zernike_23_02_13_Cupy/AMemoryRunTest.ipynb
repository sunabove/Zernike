# %%
# %%time 

from IPython.display import clear_output
clear_output()

from AMemoryRunTest import *

devices = [ "MULTI-GPU", "Multi-CPU", "GPU", "CPU" ]

test_memory_multiply_performance( devices )
# Out:
# device = multi-gpu, grid_count = 11_271, scheduler = threads, dask = 0
# Memory = 6.0977 Gb  Elapsed = 8.67 seconds
#
# device = multi-cpu, grid_count = 47_457, scheduler = threads, dask = 0
# Memory = 108.1040 Gb  Elapsed = 133.45 seconds
#
# device = gpu, grid_count = 11_271, scheduler = single-threaded, dask = 0
# Memory = 6.0977 Gb  Elapsed = 10.86 seconds
#
# device = cpu, grid_count = 47_457, scheduler = single-threaded, dask = 0
# Memory = 108.1040 Gb  Elapsed = 135.04 seconds
#
# device = multi-gpu, grid_count = 11_271, scheduler = threads, dask = 1
# Memory = 6.0977 Gb  Elapsed = 11.70 seconds
#
# device = multi-cpu, grid_count = 47_457, scheduler = threads, dask = 1
# Memory = 108.1040 Gb  Elapsed = 252.86 seconds
#
# device = gpu, grid_count = 11_271, scheduler = single-threaded, dask = 1
# Memory = 6.0977 Gb  Elapsed = 7.20 seconds
#
# device = cpu, grid_count = 47_457, scheduler = single-threaded, dask = 1
# Memory = 108.1040 Gb  Elapsed = 286.75 seconds
# CPU times: user 11min 52s, sys: 3min 56s, total: 15min 48s
# Wall time: 14min 9s

# %%
# numpy <==> cupy array conversion performance test
import numpy, cupy, math, psutil, dask.array as da
#from dask_cuda import LocalCUDACluster
#from dask.distributed import Client
from time import *
from time import perf_counter
