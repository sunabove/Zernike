# %%
from IPython.display import clear_output
clear_output()

from AZernike_06_MomentRestore import *

options = {}
options[ "debug" ] = 0 
options[ "use_gpu" ] = 1
options[ "hash" ] = {}
options[ "use_hash" ] = 1  
options[ "use_thread"] = 0 

img_infos = []
    
Ks = numpy.arange( 2, 2 + 1, 1 )
Ts = numpy.arange( 5, 32 + 1, 1 )

img = cv.imread( '../image/lenna.png', 0 )
        
test_moment_restore( img_infos, img, Ks, Ts, **options )
plot_moment_restore( img_infos, Ks, Ts, **options )

print( "\nDone." )
# Out:
# ************************************************************
# use_gpu = 1, use_hash=1, use_thread = 0
#
# ************************************************************
# K = 2, T = 5, Elapsed = 5.17(sec.)
# K = 2, T = 6, Elapsed = 0.76(sec.)
# K = 2, T = 7, Elapsed = 0.92(sec.)
# K = 2, T = 8, Elapsed = 1.16(sec.)
# K = 2, T = 9, Elapsed = 1.37(sec.)
# K = 2, T = 10, Elapsed = 1.64(sec.)
# K = 2, T = 11, Elapsed = 1.85(sec.)
# K = 2, T = 12, Elapsed = 2.19(sec.)
# K = 2, T = 13, Elapsed = 2.43(sec.)
# K = 2, T = 14, Elapsed = 2.81(sec.)
# K = 2, T = 15, Elapsed = 3.09(sec.)
# K = 2, T = 16, Elapsed = 3.51(sec.)
# K = 2, T = 17, Elapsed = 3.83(sec.)
# K = 2, T = 18, Elapsed = 4.30(sec.)
# K = 2, T = 19, Elapsed = 4.65(sec.)
# K = 2, T = 20, Elapsed = 5.17(sec.)
# K = 2, T = 21, Elapsed = 5.55(sec.)
# K = 2, T = 22, Elapsed = 6.12(sec.)
# K = 2, T = 23, Elapsed = 6.53(sec.)
# K = 2, T = 24, Elapsed = 8.73(sec.)
# K = 2, T = 25, Elapsed = 11.07(sec.)
# K = 2, T = 26, Elapsed = 10.68(sec.)
# K = 2, T = 27, Elapsed = 13.51(sec.)
# K = 2, T = 28, Elapsed = 108.25(sec.)
# K = 2, T = 29, Elapsed = 152.92(sec.)
# K = 2, T = 30, Elapsed = 144.80(sec.)
# K = 2, T = 31, Elapsed = 175.75(sec.)
# K = 2, T = 32, Elapsed = 168.90(sec.)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 21
#      18 img = cv.imread( '../image/lenna.png', 0 )
#      20 test_moment_restore( img_infos, img, Ks, Ts, **options )
# ---> 21 plot_moment_restore( img_infos, Ks, Ts )
#      23 print( "\nDone." )
#
# File ~/Zernike/Zernike_23_02_13_Cupy/AZernike_06_MomentRestore.py:129, in plot_moment_restore(img_infos, Ks, Ts)
#     125 chart = charts[ chart_idx ] ; chart_idx += 1
#     127 chart.set_title( title )
# --> 129 pos = chart.imshow( cupy.asnumpy( t_img ) if options["use_gpu"] else t_img, cmap='gray' )
#     130 colorbar and fig.colorbar(pos, ax=chart)
#     132 K_prev = K
#
# NameError: name 'options' is not defined

# %%
from IPython.display import clear_output
clear_output()

from AZernike_06_MomentRestore import *

options = {}
options[ "debug" ] = 0 
options[ "use_gpu" ] = 0
options[ "hash" ] = {}
options[ "use_hash" ] = 1  
options[ "use_thread"] = 0 

img_infos = []
    
Ks = numpy.arange( 2, 3, 1 )
Ts = numpy.arange( 5, 10 + 1, 1 )

img = cv.imread( '../image/lenna.png', 0 )
        
test_moment_restore( img_infos, img, Ks, Ts, **options )
plot_moment_restore( img_infos, Ks, Ts, **options )

print( "\nDone." )
# Out:
# ************************************************************
# use_gpu = 1, use_hash=1, use_thread = 0
#
# ************************************************************
# K = 2, T = 5, Elapsed = 1.16(sec.)
# K = 2, T = 6, Elapsed = 0.93(sec.)
# K = 2, T = 7, Elapsed = 1.15(sec.)
# K = 2, T = 8, Elapsed = 1.43(sec.)
# K = 2, T = 9, Elapsed = 1.70(sec.)
# K = 2, T = 10, Elapsed = 2.15(sec.)
# Done.

# %%
from IPython.display import clear_output
clear_output()

from AZernike_06_MomentRestore import *

options = {}
options[ "debug" ] = 0 
options[ "use_gpu" ] = 0
options[ "hash" ] = {}
options[ "use_hash" ] = 1  
options[ "use_thread"] = 0 

img_infos = []
    
Ks = numpy.arange( 2, 3, 1 )
Ts = numpy.arange( 5, 10 + 1, 1 )


img = rgb2gray( data.astronaut() )
        
test_moment_restore( img_infos, img, Ks, Ts, **options )
plot_moment_restore( img_infos, Ks, Ts,**options  )

print( "\nDone." )
# Out:
# ************************************************************
# use_gpu = 1, use_hash=1, use_thread = 0
#
# ************************************************************
# K = 2, T = 5, Elapsed = 1.13(sec.)
# K = 2, T = 6, Elapsed = 0.92(sec.)
# K = 2, T = 7, Elapsed = 1.19(sec.)
# K = 2, T = 8, Elapsed = 1.47(sec.)
# K = 2, T = 9, Elapsed = 1.76(sec.)
# K = 2, T = 10, Elapsed = 2.10(sec.)
# Done.

# %%
from IPython.display import clear_output
clear_output()

from AZernike_06_MomentRestore import *

options = {}
options[ "debug" ] = 0 
options[ "use_gpu" ] = 0
options[ "hash" ] = {}
options[ "use_hash" ] = 1  
options[ "use_thread"] = 0 

img_infos = []
    
Ks = numpy.arange( 2, 3, 1 )
Ts = numpy.arange( 5, 32 + 1, 1 )

img = data.camera()
        
test_moment_restore( img_infos, img, Ks, Ts, **options )
plot_moment_restore( img_infos, Ks, Ts, **options )

print( "\nDone." )
# Out:
# ************************************************************
# use_gpu = 0, use_hash=1, use_thread = 0
#
# ************************************************************
# K = 2, T = 5, Elapsed = 3.95(sec.)
# K = 2, T = 6, Elapsed = 2.75(sec.)
# K = 2, T = 7, Elapsed = 3.49(sec.)
# K = 2, T = 8, Elapsed = 4.57(sec.)
# K = 2, T = 9, Elapsed = 5.16(sec.)
# K = 2, T = 10, Elapsed = 6.00(sec.)
# K = 2, T = 11, Elapsed = 7.12(sec.)
# K = 2, T = 12, Elapsed = 8.17(sec.)
# K = 2, T = 13, Elapsed = 9.14(sec.)
# K = 2, T = 14, Elapsed = 11.34(sec.)
# K = 2, T = 15, Elapsed = 11.68(sec.)
# K = 2, T = 16, Elapsed = 13.39(sec.)
# K = 2, T = 17, Elapsed = 14.58(sec.)
# K = 2, T = 18, Elapsed = 16.46(sec.)
# K = 2, T = 19, Elapsed = 17.75(sec.)
# K = 2, T = 20, Elapsed = 19.25(sec.)
# K = 2, T = 21, Elapsed = 22.33(sec.)
# K = 2, T = 22, Elapsed = 22.76(sec.)
# K = 2, T = 23, Elapsed = 25.08(sec.)
# K = 2, T = 24, Elapsed = 56.91(sec.)
# K = 2, T = 25, Elapsed = 74.59(sec.)
# K = 2, T = 26, Elapsed = 75.53(sec.)
# K = 2, T = 27, Elapsed = 52.15(sec.)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 15
#      11 Ts = numpy.arange( 5, 32 + 1, 1 )
#      13 img = data.camera()
# ---> 15 test_moment_restore( img_infos, img, Ks, Ts, **options )
#      16 plot_moment_restore( img_infos, Ks, Ts )
#      18 print( "\nDone." )
#
# File <timed exec>:43, in test_moment_restore(img_infos, img_input, Ks, Ts, **options)
#
# File ~/Zernike/Zernike_23_02_13_Cupy/AZernike.py:664, in calc_moments(T, img, rho, theta, dx, dy, **options)
#     662     pass
#     663 else :
# --> 664     futures = [ _moment( p, q, rho, theta, dx, dy, use_gpu, -1 ) for idx, [p, q] in enumerate( pqs ) ]
#     665 pass
#     667 if 0 :
#
# File ~/Zernike/Zernike_23_02_13_Cupy/AZernike.py:664, in <listcomp>(.0)
#     662     pass
#     663 else :
# --> 664     futures = [ _moment( p, q, rho, theta, dx, dy, use_gpu, -1 ) for idx, [p, q] in enumerate( pqs ) ]
#     665 pass
#     667 if 0 :
#
# File ~/Zernike/Zernike_23_02_13_Cupy/AZernike.py:637, in calc_moments.<locals>._moment(p, q, rho, theta, dx, dy, use_gpu, idx)
#     635     pass
#     636 else :
# --> 637     moment = _moment_impl(p, q, rho, theta, dx, dy )
#     638 pass
#     640 moments[ p, q ] = moment
#
# File ~/Zernike/Zernike_23_02_13_Cupy/AZernike.py:644, in calc_moments.<locals>._moment_impl(p, q, rho, theta, dx, dy)
#     643 def _moment_impl(p, q, rho, theta, dx, dy):
# --> 644     v_pq = Vpq( p, q, rho, theta, **options )
#     646     moment = np.dot( v_pq, img_flat )*dx*dy
#     648     moment = np.conjugate( moment )
#
# KeyboardInterrupt:

# %%
options = {}
options[ "debug" ] = 0 
options[ "use_gpu" ] = 1
options[ "hash" ] = {}
options[ "use_hash" ] = 1  
options[ "use_thread"] = 0 

img_infos = []
    
Ks = numpy.arange( 2, 3, 1 )
Ts = numpy.arange( 5, 32 + 1, 1 )

img = data.brick()
        
test_moment_restore( img_infos, img, Ks, Ts, **options )
plot_moment_restore( img_infos, Ks, Ts, **options )

print( "\nDone." )
# Out:
# ************************************************************
# use_gpu = 1, use_hash=1, use_thread = 0
#
# ************************************************************
# K = 2, T = 5, Elapsed = 1.96(sec.)
# K = 2, T = 6, Elapsed = 1.50(sec.)
# K = 2, T = 7, Elapsed = 1.90(sec.)
# K = 2, T = 8, Elapsed = 2.32(sec.)
# K = 2, T = 9, Elapsed = 2.80(sec.)
# K = 2, T = 10, Elapsed = 3.32(sec.)
# K = 2, T = 11, Elapsed = 3.86(sec.)
# K = 2, T = 12, Elapsed = 4.64(sec.)
# K = 2, T = 13, Elapsed = 5.24(sec.)
# K = 2, T = 14, Elapsed = 6.08(sec.)
# K = 2, T = 15, Elapsed = 7.22(sec.)
# K = 2, T = 16, Elapsed = 8.37(sec.)
# K = 2, T = 17, Elapsed = 9.04(sec.)
# K = 2, T = 18, Elapsed = 10.15(sec.)
# K = 2, T = 19, Elapsed = 10.85(sec.)
# K = 2, T = 20, Elapsed = 15.87(sec.)
# K = 2, T = 21, Elapsed = 17.77(sec.)
# K = 2, T = 22, Elapsed = 20.06(sec.)
# K = 2, T = 23, Elapsed = 19.08(sec.)
# K = 2, T = 24, Elapsed = 20.86(sec.)
# K = 2, T = 25, Elapsed = 21.70(sec.)
# K = 2, T = 26, Elapsed = 31.60(sec.)
# K = 2, T = 27, Elapsed = 31.55(sec.)
# K = 2, T = 28, Elapsed = 32.99(sec.)
# K = 2, T = 29, Elapsed = 31.74(sec.)
# K = 2, T = 30, Elapsed = 38.08(sec.)
# K = 2, T = 31, Elapsed = 39.98(sec.)
# K = 2, T = 32, Elapsed = 42.90(sec.)
# Done.

# %%
options = {}
options[ "debug" ] = 0 
options[ "use_gpu" ] = 1
options[ "hash" ] = {}
options[ "use_hash" ] = 1  
options[ "use_thread"] = 0 

img_infos = []
    
Ks = numpy.arange( 2, 3, 1 )
Ts = numpy.arange( 5, 32 + 1, 1 )

img = data.moon()
        
test_moment_restore( img_infos, img, Ks, Ts, **options )
plot_moment_restore( img_infos, Ks, Ts, **options )

print( "\nDone." )
# Out:
# ************************************************************
# use_gpu = 1, use_hash=1, use_thread = 0
#
# ************************************************************
# K = 2, T = 5, Elapsed = 1.82(sec.)
# K = 2, T = 6, Elapsed = 1.47(sec.)
# K = 2, T = 7, Elapsed = 1.79(sec.)
# K = 2, T = 8, Elapsed = 2.50(sec.)
# K = 2, T = 9, Elapsed = 2.71(sec.)
# K = 2, T = 10, Elapsed = 3.29(sec.)
# K = 2, T = 11, Elapsed = 3.81(sec.)
# K = 2, T = 12, Elapsed = 4.52(sec.)
# K = 2, T = 13, Elapsed = 5.41(sec.)
# K = 2, T = 14, Elapsed = 5.81(sec.)
# K = 2, T = 15, Elapsed = 7.04(sec.)
# K = 2, T = 16, Elapsed = 7.61(sec.)
# K = 2, T = 17, Elapsed = 8.68(sec.)
# K = 2, T = 18, Elapsed = 9.64(sec.)
# K = 2, T = 19, Elapsed = 10.23(sec.)
# K = 2, T = 20, Elapsed = 11.82(sec.)
# K = 2, T = 21, Elapsed = 14.44(sec.)
# K = 2, T = 22, Elapsed = 16.60(sec.)
# K = 2, T = 23, Elapsed = 18.76(sec.)
# K = 2, T = 24, Elapsed = 21.08(sec.)
# K = 2, T = 25, Elapsed = 23.53(sec.)
# K = 2, T = 26, Elapsed = 28.35(sec.)
# K = 2, T = 27, Elapsed = 27.94(sec.)
# K = 2, T = 28, Elapsed = 29.81(sec.)
# K = 2, T = 29, Elapsed = 31.76(sec.)
# K = 2, T = 30, Elapsed = 34.77(sec.)
# K = 2, T = 31, Elapsed = 36.93(sec.)
# K = 2, T = 32, Elapsed = 39.89(sec.)
# Done.

# %%
options = {}
options[ "debug" ] = 0 
options[ "use_gpu" ] = 1
options[ "hash" ] = {}
options[ "use_hash" ] = 1  
options[ "use_thread"] = 0 

img_infos = []
    
Ks = numpy.arange( 2, 3, 1 )
Ts = numpy.arange( 5, 32 + 1, 1 )

img = data.grass()
        
test_moment_restore( img_infos, img, Ks, Ts, **options )
plot_moment_restore( img_infos, Ks, Ts, **options )

print( "\nDone." )
# Out:
# ************************************************************
# use_gpu = 1, use_hash=1, use_thread = 0
#
# ************************************************************
# K = 2, T = 5, Elapsed = 1.83(sec.)
# K = 2, T = 6, Elapsed = 1.47(sec.)
# K = 2, T = 7, Elapsed = 1.73(sec.)
# K = 2, T = 8, Elapsed = 2.48(sec.)
# K = 2, T = 9, Elapsed = 2.75(sec.)
# K = 2, T = 10, Elapsed = 3.38(sec.)
# K = 2, T = 11, Elapsed = 3.72(sec.)
# K = 2, T = 12, Elapsed = 4.41(sec.)
# K = 2, T = 13, Elapsed = 5.02(sec.)
# K = 2, T = 14, Elapsed = 6.05(sec.)
# K = 2, T = 15, Elapsed = 6.49(sec.)
# K = 2, T = 16, Elapsed = 7.77(sec.)
# K = 2, T = 17, Elapsed = 8.62(sec.)
# K = 2, T = 18, Elapsed = 9.40(sec.)
# K = 2, T = 19, Elapsed = 10.46(sec.)
# K = 2, T = 20, Elapsed = 11.62(sec.)
# K = 2, T = 21, Elapsed = 13.52(sec.)
# K = 2, T = 22, Elapsed = 16.54(sec.)
# K = 2, T = 23, Elapsed = 18.48(sec.)
# K = 2, T = 24, Elapsed = 20.96(sec.)
# K = 2, T = 25, Elapsed = 23.89(sec.)
# K = 2, T = 26, Elapsed = 26.32(sec.)
# K = 2, T = 27, Elapsed = 28.44(sec.)
# K = 2, T = 28, Elapsed = 32.12(sec.)
# K = 2, T = 29, Elapsed = 33.06(sec.)
# K = 2, T = 30, Elapsed = 34.23(sec.)
# K = 2, T = 31, Elapsed = 37.00(sec.)
# K = 2, T = 32, Elapsed = 35.56(sec.)
# Done.
